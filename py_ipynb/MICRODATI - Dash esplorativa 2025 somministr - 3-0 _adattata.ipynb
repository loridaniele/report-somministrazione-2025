# %%
MICRODATI -DASH di esplorazione dati 3.0

# %%
# variazione di 'Dash - esercizi - new - 5' in chiave 
# variazione di 'MICRODATI - esplorazione 2025 somministrazione - 1, 2,3,4,5'
# variazione di 'MICRODATI -DASH di esplorazione dati 2.0'
# esplorazione somministrazione 2025 in MICRODATI
# 
#27/04/2026 versione funzionante ed abbastanza stabile
# BASE di sviluppo ulteriore

# %%
# ispirato da 
#https://github.com/plotly/tutorial-code/blob/main/session4/annex_b.py


#!pip install dash --upgrade
#!pip install dash-bootstrap-components

#1b. import libreries

#----------------------solo per WasmDash
#import micropip
#await micropip.install('dash-bootstrap-components')
#----------------------


import dash
import flask  # <--- Questo mancava!
import werkzeug

print(f"Dash version: {dash.__version__}")
print(f"Flask version: {flask.__version__}")
print(f"Werkzeug version: {werkzeug.__version__}")
#print(f"Dash_bootstrap_components version: {dash_bootstrap_components.__version__}")
#----------------

from dash import Dash, html, dcc, callback, Input, Output, State, no_update
import dash_bootstrap_components as dbc
import pandas as pd
import plotly.express as px

#------------------
# %run ../../Libreria_JUPITER.ipynb
#run ../MICRODATI_funzioni.ipynb
# Out:
# Dash version: 4.1.0
# Flask version: 2.3.2
# Werkzeug version: 2.3.3

# %%
dir_save_dati= "C:\\Users\\lorid\\OneDrive\\Documenti\\Lavori_vari\\sistal_2\\eventi_SO\\eventi_SO_somministrazione_2025"
target_file=fr"{dir_save_dati}\\MICRO_SO_1525_5digit.csv"

df = pd.read_csv(target_file)
df.columns
# Out:
# C:\Users\lorid\AppData\Local\Temp\ipykernel_6412\3257694105.py:4: DtypeWarning:
#
# Columns (40,41,42) have mixed types. Specify dtype option on import or set low_memory=False.
# Index(['Unnamed: 0.4', 'Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1',
#        'Unnamed: 0', 'ID_RAPPORTO', 'DATA_EVENTO', 'ANNO_EVENTO',
#        'MESE_EVENTO', 'TIPO_EVENTO', 'CODICE_TRASFORMAZIONE',
#        'CODICE_CAUSA_CESSAZIONE', 'CODICE_FISCALE_DATORE', 'RAGSOCDATLAV',
#        'CODICE_FISCALE_LAVORATORE', 'COD_TIPOLOGIA_CONTRATTUALE',
#        'COD_TIPO_ORARIO', 'COMUNE_LAVORATORE_COB', 'COMUNE_LAVORATORE',
#        'CAP_LAVORATORE', 'SESSO_LAV', 'DATA_NASCITA_LAV', 'ANNO_NASCITA_LAV',
#        'MESE_NASCITA_LAV', 'ETA_LAV', 'NAZIONALITA_LAV', 'LIV_ISTRUZIONE_LAV',
#        'ATECO_SETTORE_COB', 'ATECO_GRUPPO', 'CLASSIFICAZIONE_DATORE',
#        'TIPO_DATORE', 'COMUNE_SEDE_LAVORO_COB', 'COMUNE_SEDE_LAVORO',
#        'CAP_SEDE_LAVORO', 'ORE_SETTIM_MEDIE', 'COD_QUALIFICA_PROF_ISTAT_COB',
#        'COD_QUALIFICA_PROF_ISTAT_3DGT', 'CCNL', 'RETRIBUZIONE', 'CATEGORIA',
#        'ID_SOMMINISTRAZIONE', 'CODICE_FISCALE_AGENZIA_SOMMIN', 'RAGSOCSOMM',
#        'nome_comune_lavoratore', 'nome_provincia_lavoratore',
#        'nome_regione_lavoratore', 'nome_CPI_lavoratore',
#        'nome_comune_sede_lavoro', 'nome_provincia_sede_lavoro',
#        'nome_regione_sede_lavoro', 'nome_CPI_sede_lavoro', 'qualifiche_cp2021',
#        'ateco2007', 'ateco2007_COB', 'ateco2007_SEZIONE',
#        'ateco2007_SEZIONE_NOME', 'ateco2007_DIVISIONE',
#        'ateco2007_DIVISIONE_NOME', 'ateco2007_GRUPPO_NOME',
#        'DES_TRASFORMAZIONE', 'NAZIONALITA', 'POP_TOT_COMUNE_LAVORATORE',
#        'POP_TOT_COMUNE_SEDE_LAVORO', 'POP_TOT_CPI_LAVORATORE',
#        'POP_TOT_CPI_SEDE_LAVORO', 'TIPOLOGIA_CONTRATTUALE',
#        'COD_QUALIFICA_PROF_ISTAT_5DGT', 'qualifiche_cp2021_5digit',
#        'Codice CP2011_x', 'Descrizione CP2021', 'Codice CP2011_y',
#        'ETA_LAV_ISTAT'],
#       dtype='object')

# %%
#########################
funziona
#########################

# %%
##########################################
#       funzionante
##########################################

# %%
import dash
from dash import dcc, html, Input, Output, callback, dash_table, State
import plotly.express as px
import pandas as pd
import dash_bootstrap_components as dbc
import os

# --- 0. PREPARAZIONE CARTELLA ESPORTAZIONE ---
# Il "../" dice a Python di tornare alla directory padre
export_dir = os.path.join("..", "esportazioni_quarto")
if not os.path.exists(export_dir):
    os.makedirs(export_dir)

# --- FUNZIONE: FORZA UTF-8 PER ACCENTI ---
def force_utf8(filepath):
    """Corregge i byte ANSI (\xe0) in UTF-8 per le vocali accentate"""
    try:
        with open(filepath, 'r', encoding='iso-8859-1') as f:
            content = f.read()
        with open(filepath, 'w', encoding='utf-8') as f:
            f.write(content)
    except Exception as e:
        print(f"Errore force_utf8: {e}")

# --- 1. CONFIGURAZIONE E DATI ---

# Dizionario di traduzione per i nomi dei campi nelle legende e negli hover
MAPPA_NOMI_VISTE = {
    'nome_CPI_sede_lavoro': "Centro per l'Impiego",
    'qualifiche_cp2021_5digit': "Qualifica Professionale",
    'ateco2007_DIVISIONE_NOME': "Settore ATECO",
    'SESSO_LAV': "Genere",
    'ETA_LAV_ISTAT': "Fascia d'Età ISTAT",
    'TIPO_EVENTO': "Tipologia Evento",
    'NAZIONALITA': "Nazionalità",
    'ANNO_EVENTO': "Anno"
}

color_map_sesso = {'F': '#e74c3c', 'M': '#3498db'}
min_age, max_age = int(df['ETA_LAV'].min()), int(df['ETA_LAV'].max())

def get_options(col_name):
    return [{'label': str(val), 'value': val} for val in sorted(df[col_name].unique())]

# --- 2. LAYOUT ---
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container([
    dcc.Store(id='store-contratto-sel', data=None),
    dcc.Store(id='store-target-sel', data=None),
    
    html.H1('BI: Analisi Mercato del Lavoro', className="mt-3 text-primary fw-bold"),
    html.Hr(),
    
    dbc.Card([
        dbc.CardBody([
            dbc.Row([
                dbc.Col([html.Label("Anno"), dcc.Dropdown(id='f-anno', options=get_options('ANNO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Sesso"), dcc.Dropdown(id='f-sesso', options=get_options('SESSO_LAV'), multi=True)], width=2),
                dbc.Col([html.Label("Tipo Evento"), dcc.Dropdown(id='f-evento', options=get_options('TIPO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Nazionalità"), dcc.Dropdown(id='f-nazionalita', options=get_options('NAZIONALITA'), multi=True)], width=3),
                dbc.Col([html.Label("CPI"), dcc.Dropdown(id='f-cpi', options=get_options('nome_CPI_sede_lavoro'), multi=True)], width=3),
            ], className="mb-3"),
            dbc.Row([
                dbc.Col([
                    html.Label("Analisi Dettaglio:", className="fw-bold text-danger"),
                    dcc.RadioItems(
                        id='target-dimension',
                        options=[{'label': ' Qualifiche', 'value': 'qualifiche_cp2021_5digit'},
                                 {'label': ' Settore ATECO', 'value': 'ateco2007_DIVISIONE_NOME'}],
                        value='qualifiche_cp2021_5digit', inline=True,
                        inputStyle={"margin-left": "20px", "margin-right": "5px"}
                    )
                ], width=6),
                dbc.Col([html.Label("Età"), dcc.RangeSlider(id='f-eta', min=min_age, max=max_age, value=[min_age, max_age])], width=6),
            ])
        ])
    ], className="mb-4 shadow-sm border-0"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader("1. Contratti"), dbc.CardBody(dcc.Graph(id='graph-contracts'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader("2. Dettaglio"), dbc.CardBody(dcc.Graph(id='graph-target'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-3'), dbc.CardBody(dcc.Graph(id='trend-contracts-sesso'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-4'), dbc.CardBody(dcc.Graph(id='trend-target-sesso'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-5'), dbc.CardBody(dcc.Graph(id='trend-contracts-evento'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-6'), dbc.CardBody(dcc.Graph(id='trend-target-evento'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-7'), dbc.CardBody(dcc.Graph(id='trend-contracts-naz'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-8'), dbc.CardBody(dcc.Graph(id='trend-target-naz'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-9'), dbc.CardBody(dcc.Graph(id='trend-contracts-cpi'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-10'), dbc.CardBody(dcc.Graph(id='trend-target-cpi'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-11'), dbc.CardBody(dcc.Graph(id='trend-contracts-eta'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-12'), dbc.CardBody(dcc.Graph(id='trend-target-eta'))]), width=6),
    ], className="mb-4"),

    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader("Riepilogo Numerico"), dbc.CardBody(id='table-container')]), width=12)])
], fluid=True)

# --- 3. LOGICA FILTRI E RIFINITURA ---
def get_filtered_df(anno, sesso, evento, naz, cpi, eta):
    dff = df.copy()
    if anno: dff = dff[dff['ANNO_EVENTO'].isin(anno)]
    if sesso: dff = dff[dff['SESSO_LAV'].isin(sesso)]
    if evento: dff = dff[dff['TIPO_EVENTO'].isin(evento)]
    if naz: dff = dff[dff['NAZIONALITA'].isin(naz)]
    if cpi: dff = dff[dff['nome_CPI_sede_lavoro'].isin(cpi)]
    if eta: dff = dff[(dff['ETA_LAV'] >= eta[0]) & (dff['ETA_LAV'] <= eta[1])]
    return dff

def refine_fig_layout(fig):
    # --- 1. PULIZIA TITOLO LEGENDA ---
    titolo_legenda = fig.layout.legend.title.text if fig.layout.legend.title and fig.layout.legend.title.text else None
    
    if titolo_legenda:
        if titolo_legenda in MAPPA_NOMI_VISTE:
            titolo_legenda = MAPPA_NOMI_VISTE[titolo_legenda]
        else:
            titolo_legenda = titolo_legenda.replace('_', ' ')

    # --- 2. PULIZIA HOVER (TOOLTIPS) ---
    for trace in fig.data:
        if trace.hovertemplate:
            for nome_grezzo, nome_bello in MAPPA_NOMI_VISTE.items():
                trace.hovertemplate = trace.hovertemplate.replace(nome_grezzo, nome_bello)
            trace.hovertemplate = trace.hovertemplate.replace('_', ' ')

    # --- 3. APPLICAZIONE LAYOUT E MARGINI ---
    fig.update_layout(
        xaxis_title=None,
        yaxis_title=None,
        margin=dict(l=250, r=120, t=60, b=50), 
        legend=dict(
            title_text=titolo_legenda,
            orientation="v",
            yanchor="middle",
            y=0.5,
            xanchor="left",
            x=1.02,
            font=dict(size=10)
        )
    )
    return fig

# --- 4. CALLBACKS ---

@callback(Output('store-contratto-sel', 'data'), Input('graph-contracts', 'clickData'), State('store-contratto-sel', 'data'))
def toggle_c(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(Output('store-target-sel', 'data'), Input('graph-target', 'clickData'), State('store-target-sel', 'data'))
def toggle_t(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(
    [Output('graph-contracts', 'figure'), Output('table-container', 'children')],
    [Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-contratto-sel', 'data')]
)
def update_g1(anno, sesso, evento, naz, cpi, eta, sel_c):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
    
    top = dff['VIZ'].value_counts().nlargest(25).reset_index()
    top.columns = ['VIZ', 'count']
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1)
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    colors = ['#e74c3c' if v == sel_c else ('#2c3e50' if sel_c is None else '#bdc3c7') for v in top['VIZ']]
    
    fig = px.bar(top, y='VIZ', x='count', orientation='h', template="plotly_white", text='label_text')
    fig.update_traces(marker_color=colors, textposition=['inside']*3 + ['outside']*(len(top)-3), textfont_color=['white']*3 + ['black']*(len(top)-3))
    fig = refine_fig_layout(fig)
    fig.update_layout(height=700)
    
    try:
        fig.write_html(f"{export_dir}/grafico_1.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_1.png")
        force_utf8(f"{export_dir}/grafico_1.html")
    except Exception as e:
        print(f"Salvataggio in background fallito per grafico 1: {e}")
        pass
    
    pivot = pd.crosstab(dff['VIZ'], dff['SESSO_LAV'], margins=True).reset_index()
    return fig, dash_table.DataTable(data=pivot.to_dict('records'), columns=[{"name": str(i), "id": str(i)} for i in pivot.columns], page_size=10)

@callback(
    Output('graph-target', 'figure'),
    [Input('store-contratto-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-target-sel', 'data')]
)
def update_g2(sel_c, target_dim, anno, sesso, evento, naz, cpi, eta, sel_t):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    if sel_c:
        dff['VIZ_C'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        dff = dff[dff['VIZ_C'] == sel_c]
    
    top = dff[target_dim].value_counts().nlargest(25).reset_index()
    top.columns = [target_dim, 'count']
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1)
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    colors = ['#e74c3c' if v == sel_t else ('#16a085' if sel_t is None else '#bdc3c7') for v in top[target_dim]]
    
    fig = px.bar(top, y=target_dim, x='count', orientation='h', template="plotly_white", text='label_text')
    fig.update_traces(marker_color=colors, textposition=['inside']*3 + ['outside']*(len(top)-3), textfont_color=['white']*3 + ['black']*(len(top)-3))
    fig = refine_fig_layout(fig)
    fig.update_layout(height=700)
    
    try:
        fig.write_html(f"{export_dir}/grafico_2.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_2.png")
        force_utf8(f"{export_dir}/grafico_2.html")
    except Exception as e:
        print(f"Salvataggio in background fallito per grafico 2: {e}")
        pass
    
    return fig

@callback(
    [Output('trend-contracts-sesso', 'figure'), Output('trend-contracts-evento', 'figure'),
     Output('trend-contracts-naz', 'figure'), Output('trend-contracts-cpi', 'figure'),
     Output('trend-contracts-eta', 'figure'), 
     Output('title-3', 'children'), Output('title-5', 'children'),
     Output('title-7', 'children'), Output('title-9', 'children'),
     Output('title-11', 'children')], 
    [Input('store-contratto-sel', 'data'), Input('f-anno', 'value'), Input('f-sesso', 'value'), 
     Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_left(sel_c, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    label = sel_c if sel_c else "Tutti i contratti"
    if sel_c:
        dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        dff = dff[dff['VIZ'] == sel_c]
    
    f3 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f5 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    
    # --- MODIFICA GRAFICO 7: TOP 25 NAZIONALITÀ ---
    top_25_naz_left = dff['NAZIONALITA'].value_counts().nlargest(25).index.tolist()
    dff_f7 = dff[dff['NAZIONALITA'].isin(top_25_naz_left)]
    f7 = px.line(dff_f7.groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), 
                 x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, 
                 title=f"Trend Nazionalità: {label}",
                 category_orders={"NAZIONALITA": top_25_naz_left})
    
    f9 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f11 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età ISTAT: {label}")
    
    for idx, f in enumerate([f3, f5, f7, f9, f11]): 
        f = refine_fig_layout(f)
        f.update_layout(xaxis=dict(dtick=1), template="plotly_white")
        num = 3 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except Exception as e:
            print(f"Salvataggio in background fallito per grafico {num}: {e}")
            pass
            
    return f3, f5, f7, f9, f11, f"3. {label}", f"5. {label}", f"7. {label}", f"9. {label}", f"11. {label}"

@callback(
    [Output('trend-target-sesso', 'figure'), Output('trend-target-evento', 'figure'),
     Output('trend-target-naz', 'figure'), Output('trend-target-cpi', 'figure'),
     Output('trend-target-eta', 'figure'), 
     Output('title-4', 'children'), Output('title-6', 'children'),
     Output('title-8', 'children'), Output('title-10', 'children'),
     Output('title-12', 'children')], 
    [Input('store-target-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_right(sel_t, target_dim, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    if sel_t:
        dff = dff[dff[target_dim] == sel_t]
        label = sel_t
    else:
        top_25 = dff[target_dim].value_counts().nlargest(25).index
        dff = dff[dff[target_dim].isin(top_25)]
        label = "Top 25 " + ("Qualifiche" if target_dim == 'qualifiche_cp2021_5digit' else "Settore ATECO")
    
    f4 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f6 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    
    # --- MODIFICA GRAFICO 8: TOP 25 NAZIONALITÀ ---
    top_25_naz_right = dff['NAZIONALITA'].value_counts().nlargest(25).index.tolist()
    dff_f8 = dff[dff['NAZIONALITA'].isin(top_25_naz_right)]
    f8 = px.line(dff_f8.groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), 
                 x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, 
                 title=f"Trend Nazionalità: {label}",
                 category_orders={"NAZIONALITA": top_25_naz_right})

    f10 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f12 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età ISTAT: {label}")
    
    for idx, f in enumerate([f4, f6, f8, f10, f12]): 
        f = refine_fig_layout(f)
        f.update_layout(xaxis=dict(dtick=1), template="plotly_white")
        num = 4 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except Exception as e:
            print(f"Salvataggio in background fallito per grafico {num}: {e}")
            pass
            
    return f4, f6, f8, f10, f12, f"4. {label}", f"6. {label}", f"8. {label}", f"10. {label}", f"12. {label}"

if __name__ == '__main__':
    app.run(mode="inline", port=8050)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
############## last version

# %%
import dash
from dash import dcc, html, Input, Output, callback, dash_table, State
import plotly.express as px
import pandas as pd
import dash_bootstrap_components as dbc
import os

####################  fondamentale: dove vengono salvati i grafici
# in questo caso la dir di salvataggio ' esportaz..' è una parallela
# rispetto alla cartella dove si trova la dash

# --- 0. PREPARAZIONE CARTELLA ESPORTAZIONE ---
export_dir = os.path.join("..", "esportazioni_quarto") # Modificato per allinearlo alla tua richiesta precedente, cambialo se serve
if not os.path.exists(export_dir):
    os.makedirs(export_dir)
#################################################################

# --- FUNZIONE: FORZA UTF-8 PER ACCENTI ---
def force_utf8(filepath):
    """Corregge i byte ANSI (\xe0) in UTF-8 per le vocali accentate"""
    try:
        with open(filepath, 'r', encoding='iso-8859-1') as f:
            content = f.read()
        with open(filepath, 'w', encoding='utf-8') as f:
            f.write(content)
    except Exception as e:
        print(f"Errore force_utf8: {e}")

# --- 1. CONFIGURAZIONE E DATI ---

MAPPA_NOMI_VISTE = {
    'nome_CPI_sede_lavoro': "Centro per l'Impiego",
    'qualifiche_cp2021_5digit': "Qualifica Professionale",
    'ateco2007_DIVISIONE_NOME': "Settore ATECO",
    'SESSO_LAV': "Genere",
    'ETA_LAV_ISTAT': "Fascia d'Età ISTAT",
    'TIPO_EVENTO': "Tipologia Evento",
    'NAZIONALITA': "Nazionalità",
    'ANNO_EVENTO': "Anno"
}

color_map_sesso = {'F': '#e74c3c', 'M': '#3498db'}
min_age, max_age = int(df['ETA_LAV'].min()), int(df['ETA_LAV'].max())

def get_options(col_name):
    return [{'label': str(val), 'value': val} for val in sorted(df[col_name].unique())]

# --- 2. LAYOUT ---
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container([
    dcc.Store(id='store-contratto-sel', data=None),
    dcc.Store(id='store-target-sel', data=None),
    
    html.H1('BI: Analisi Mercato del Lavoro', className="mt-3 text-primary fw-bold"),
    html.Hr(),
    
    dbc.Card([
        dbc.CardBody([
            dbc.Row([
                dbc.Col([html.Label("Anno"), dcc.Dropdown(id='f-anno', options=get_options('ANNO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Sesso"), dcc.Dropdown(id='f-sesso', options=get_options('SESSO_LAV'), multi=True)], width=2),
                dbc.Col([html.Label("Tipo Evento"), dcc.Dropdown(id='f-evento', options=get_options('TIPO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Nazionalità"), dcc.Dropdown(id='f-nazionalita', options=get_options('NAZIONALITA'), multi=True)], width=3),
                dbc.Col([html.Label("CPI"), dcc.Dropdown(id='f-cpi', options=get_options('nome_CPI_sede_lavoro'), multi=True)], width=3),
            ], className="mb-3"),
            dbc.Row([
                dbc.Col([
                    html.Label("Analisi Dettaglio:", className="fw-bold text-danger"),
                    dcc.RadioItems(
                        id='target-dimension',
                        options=[{'label': ' Qualifiche', 'value': 'qualifiche_cp2021_5digit'},
                                 {'label': ' Settore ATECO', 'value': 'ateco2007_DIVISIONE_NOME'}],
                        value='qualifiche_cp2021_5digit', inline=True,
                        inputStyle={"margin-left": "20px", "margin-right": "5px"}
                    )
                ], width=6),
                dbc.Col([html.Label("Età"), dcc.RangeSlider(id='f-eta', min=min_age, max=max_age, value=[min_age, max_age])], width=6),
            ])
        ])
    ], className="mb-4 shadow-sm border-0"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader("1. Contratti"), dbc.CardBody(dcc.Graph(id='graph-contracts'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader("2. Dettaglio"), dbc.CardBody(dcc.Graph(id='graph-target'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-3'), dbc.CardBody(dcc.Graph(id='trend-contracts-sesso'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-4'), dbc.CardBody(dcc.Graph(id='trend-target-sesso'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-5'), dbc.CardBody(dcc.Graph(id='trend-contracts-evento'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-6'), dbc.CardBody(dcc.Graph(id='trend-target-evento'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-7'), dbc.CardBody(dcc.Graph(id='trend-contracts-naz'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-8'), dbc.CardBody(dcc.Graph(id='trend-target-naz'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-9'), dbc.CardBody(dcc.Graph(id='trend-contracts-cpi'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-10'), dbc.CardBody(dcc.Graph(id='trend-target-cpi'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-11'), dbc.CardBody(dcc.Graph(id='trend-contracts-eta'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-12'), dbc.CardBody(dcc.Graph(id='trend-target-eta'))]), width=6),
    ], className="mb-4"),

    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader("Riepilogo Numerico"), dbc.CardBody(id='table-container')]), width=12)])
], fluid=True)

# --- 3. LOGICA FILTRI E RIFINITURA ---
def get_filtered_df(anno, sesso, evento, naz, cpi, eta):
    dff = df.copy()
    if anno: dff = dff[dff['ANNO_EVENTO'].isin(anno)]
    if sesso: dff = dff[dff['SESSO_LAV'].isin(sesso)]
    if evento: dff = dff[dff['TIPO_EVENTO'].isin(evento)]
    if naz: dff = dff[dff['NAZIONALITA'].isin(naz)]
    if cpi: dff = dff[dff['nome_CPI_sede_lavoro'].isin(cpi)]
    if eta: dff = dff[(dff['ETA_LAV'] >= eta[0]) & (dff['ETA_LAV'] <= eta[1])]
    return dff

def refine_fig_layout(fig):
    titolo_legenda = fig.layout.legend.title.text if fig.layout.legend.title and fig.layout.legend.title.text else None
    
    if titolo_legenda:
        if titolo_legenda in MAPPA_NOMI_VISTE:
            titolo_legenda = MAPPA_NOMI_VISTE[titolo_legenda]
        else:
            titolo_legenda = titolo_legenda.replace('_', ' ')

    for trace in fig.data:
        if trace.hovertemplate:
            for nome_grezzo, nome_bello in MAPPA_NOMI_VISTE.items():
                trace.hovertemplate = trace.hovertemplate.replace(nome_grezzo, nome_bello)
            trace.hovertemplate = trace.hovertemplate.replace('_', ' ')

    fig.update_layout(
        xaxis_title=None,
        yaxis_title=None,
        margin=dict(l=250, r=120, t=60, b=50), 
        legend=dict(
            title_text=titolo_legenda,
            orientation="v",
            yanchor="middle",
            y=0.5,
            xanchor="left",
            x=1.02,
            font=dict(size=10)
        )
    )
    return fig

# --- 4. CALLBACKS ---

@callback(Output('store-contratto-sel', 'data'), Input('graph-contracts', 'clickData'), State('store-contratto-sel', 'data'))
def toggle_c(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(Output('store-target-sel', 'data'), Input('graph-target', 'clickData'), State('store-target-sel', 'data'))
def toggle_t(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(
    [Output('graph-contracts', 'figure'), Output('table-container', 'children')],
    [Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-contratto-sel', 'data')]
)
def update_g1(anno, sesso, evento, naz, cpi, eta, sel_c):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
    
    top = dff['VIZ'].value_counts().nlargest(25).reset_index()
    top.columns = ['VIZ', 'count']
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1)
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    colors = ['#e74c3c' if v == sel_c else ('#2c3e50' if sel_c is None else '#bdc3c7') for v in top['VIZ']]
    
    # AGGIUNTO IL TITOLO QUI!
    fig = px.bar(top, y='VIZ', x='count', orientation='h', template="plotly_white", text='label_text', title="Top 25 Tipologie Contrattuali")
    fig.update_traces(marker_color=colors, textposition=['inside']*3 + ['outside']*(len(top)-3), textfont_color=['white']*3 + ['black']*(len(top)-3))
    fig = refine_fig_layout(fig)
    fig.update_layout(height=700)
    
    try:
        fig.write_html(f"{export_dir}/grafico_1.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_1.png")
        force_utf8(f"{export_dir}/grafico_1.html")
    except Exception as e:
        print(f"Salvataggio in background fallito per grafico 1: {e}")
        pass
    
    pivot = pd.crosstab(dff['VIZ'], dff['SESSO_LAV'], margins=True).reset_index()
    return fig, dash_table.DataTable(data=pivot.to_dict('records'), columns=[{"name": str(i), "id": str(i)} for i in pivot.columns], page_size=10)

@callback(
    Output('graph-target', 'figure'),
    [Input('store-contratto-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-target-sel', 'data')]
)
def update_g2(sel_c, target_dim, anno, sesso, evento, naz, cpi, eta, sel_t):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    if sel_c:
        dff['VIZ_C'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        dff = dff[dff['VIZ_C'] == sel_c]
    
    top = dff[target_dim].value_counts().nlargest(25).reset_index()
    top.columns = [target_dim, 'count']
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1)
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    colors = ['#e74c3c' if v == sel_t else ('#16a085' if sel_t is None else '#bdc3c7') for v in top[target_dim]]
    
    # AGGIUNTO IL TITOLO DINAMICO QUI!
    nome_dimensione = "Qualifiche" if target_dim == 'qualifiche_cp2021_5digit' else "Settore ATECO"
    nome_contratto = sel_c if sel_c else "Tutti i contratti"
    titolo_dinamico_g2 = f"Top 25 {nome_dimensione} ({nome_contratto})"

    fig = px.bar(top, y=target_dim, x='count', orientation='h', template="plotly_white", text='label_text', title=titolo_dinamico_g2)
    fig.update_traces(marker_color=colors, textposition=['inside']*3 + ['outside']*(len(top)-3), textfont_color=['white']*3 + ['black']*(len(top)-3))
    fig = refine_fig_layout(fig)
    fig.update_layout(height=700)
    
    try:
        fig.write_html(f"{export_dir}/grafico_2.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_2.png")
        force_utf8(f"{export_dir}/grafico_2.html")
    except Exception as e:
        print(f"Salvataggio in background fallito per grafico 2: {e}")
        pass
    
    return fig

@callback(
    [Output('trend-contracts-sesso', 'figure'), Output('trend-contracts-evento', 'figure'),
     Output('trend-contracts-naz', 'figure'), Output('trend-contracts-cpi', 'figure'),
     Output('trend-contracts-eta', 'figure'), 
     Output('title-3', 'children'), Output('title-5', 'children'),
     Output('title-7', 'children'), Output('title-9', 'children'),
     Output('title-11', 'children')], 
    [Input('store-contratto-sel', 'data'), Input('f-anno', 'value'), Input('f-sesso', 'value'), 
     Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_left(sel_c, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    label = sel_c if sel_c else "Tutti i contratti"
    if sel_c:
        dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        dff = dff[dff['VIZ'] == sel_c]
    
    f3 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f5 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    
    top_25_naz_left = dff['NAZIONALITA'].value_counts().nlargest(25).index.tolist()
    dff_f7 = dff[dff['NAZIONALITA'].isin(top_25_naz_left)]
    f7 = px.line(dff_f7.groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), 
                 x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, 
                 title=f"Trend Nazionalità: {label}",
                 category_orders={"NAZIONALITA": top_25_naz_left})
    
    f9 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f11 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età ISTAT: {label}")
    
    for idx, f in enumerate([f3, f5, f7, f9, f11]): 
        f = refine_fig_layout(f)
        f.update_layout(xaxis=dict(dtick=1), template="plotly_white")
        num = 3 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except Exception as e:
            print(f"Salvataggio in background fallito per grafico {num}: {e}")
            pass
            
    return f3, f5, f7, f9, f11, f"3. {label}", f"5. {label}", f"7. {label}", f"9. {label}", f"11. {label}"

@callback(
    [Output('trend-target-sesso', 'figure'), Output('trend-target-evento', 'figure'),
     Output('trend-target-naz', 'figure'), Output('trend-target-cpi', 'figure'),
     Output('trend-target-eta', 'figure'), 
     Output('title-4', 'children'), Output('title-6', 'children'),
     Output('title-8', 'children'), Output('title-10', 'children'),
     Output('title-12', 'children')], 
    [Input('store-target-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_right(sel_t, target_dim, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    if sel_t:
        dff = dff[dff[target_dim] == sel_t]
        label = sel_t
    else:
        top_25 = dff[target_dim].value_counts().nlargest(25).index
        dff = dff[dff[target_dim].isin(top_25)]
        label = "Top 25 " + ("Qualifiche" if target_dim == 'qualifiche_cp2021_5digit' else "Settore ATECO")
    
    f4 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f6 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    
    top_25_naz_right = dff['NAZIONALITA'].value_counts().nlargest(25).index.tolist()
    dff_f8 = dff[dff['NAZIONALITA'].isin(top_25_naz_right)]
    f8 = px.line(dff_f8.groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), 
                 x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, 
                 title=f"Trend Nazionalità: {label}",
                 category_orders={"NAZIONALITA": top_25_naz_right})

    f10 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f12 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età ISTAT: {label}")
    
    for idx, f in enumerate([f4, f6, f8, f10, f12]): 
        f = refine_fig_layout(f)
        f.update_layout(xaxis=dict(dtick=1), template="plotly_white")
        num = 4 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except Exception as e:
            print(f"Salvataggio in background fallito per grafico {num}: {e}")
            pass
            
    return f4, f6, f8, f10, f12, f"4. {label}", f"6. {label}", f"8. {label}", f"10. {label}", f"12. {label}"

if __name__ == '__main__':
    app.run(mode="inline", port=8051)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8051/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#------------ inserisco un diverso grafico 1 con una categoria 'Altro'

# %%
import dash
from dash import dcc, html, Input, Output, callback, dash_table, State
import plotly.express as px
import pandas as pd
import dash_bootstrap_components as dbc
import os

# --- 0. PREPARAZIONE CARTELLA ESPORTAZIONE ---
export_dir = os.path.join("..", "esportazioni_quarto") 
if not os.path.exists(export_dir):
    os.makedirs(export_dir)

# --- FUNZIONE: FORZA UTF-8 PER ACCENTI ---
def force_utf8(filepath):
    """Corregge i byte ANSI (\xe0) in UTF-8 per le vocali accentate"""
    try:
        with open(filepath, 'r', encoding='iso-8859-1') as f:
            content = f.read()
        with open(filepath, 'w', encoding='utf-8') as f:
            f.write(content)
    except Exception as e:
        print(f"Errore force_utf8: {e}")

# --- 1. CONFIGURAZIONE E DATI ---

MAPPA_NOMI_VISTE = {
    'nome_CPI_sede_lavoro': "Centro per l'Impiego",
    'qualifiche_cp2021_5digit': "Qualifica Professionale",
    'ateco2007_DIVISIONE_NOME': "Settore ATECO",
    'SESSO_LAV': "Genere",
    'ETA_LAV_ISTAT': "Fascia d'Età ISTAT",
    'TIPO_EVENTO': "Tipologia Evento",
    'NAZIONALITA': "Nazionalità",
    'ANNO_EVENTO': "Anno"
}

color_map_sesso = {'F': '#e74c3c', 'M': '#3498db'}

# NOTA: Assicurati che il tuo DataFrame 'df' sia caricato prima di questo punto nel tuo script reale
min_age, max_age = int(df['ETA_LAV'].min()), int(df['ETA_LAV'].max())

def get_options(col_name):
    return [{'label': str(val), 'value': val} for val in sorted(df[col_name].unique())]

# --- 2. LAYOUT ---
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container([
    dcc.Store(id='store-contratto-sel', data=None),
    dcc.Store(id='store-target-sel', data=None),
    
    html.H1('BI: Analisi Mercato del Lavoro', className="mt-3 text-primary fw-bold"),
    html.Hr(),
    
    dbc.Card([
        dbc.CardBody([
            dbc.Row([
                dbc.Col([html.Label("Anno"), dcc.Dropdown(id='f-anno', options=get_options('ANNO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Sesso"), dcc.Dropdown(id='f-sesso', options=get_options('SESSO_LAV'), multi=True)], width=2),
                dbc.Col([html.Label("Tipo Evento"), dcc.Dropdown(id='f-evento', options=get_options('TIPO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Nazionalità"), dcc.Dropdown(id='f-nazionalita', options=get_options('NAZIONALITA'), multi=True)], width=3),
                dbc.Col([html.Label("CPI"), dcc.Dropdown(id='f-cpi', options=get_options('nome_CPI_sede_lavoro'), multi=True)], width=3),
            ], className="mb-3"),
            dbc.Row([
                dbc.Col([
                    html.Label("Analisi Dettaglio:", className="fw-bold text-danger"),
                    dcc.RadioItems(
                        id='target-dimension',
                        options=[{'label': ' Qualifiche', 'value': 'qualifiche_cp2021_5digit'},
                                 {'label': ' Settore ATECO', 'value': 'ateco2007_DIVISIONE_NOME'}],
                        value='qualifiche_cp2021_5digit', inline=True,
                        inputStyle={"margin-left": "20px", "margin-right": "5px"}
                    )
                ], width=6),
                dbc.Col([html.Label("Età"), dcc.RangeSlider(id='f-eta', min=min_age, max=max_age, value=[min_age, max_age])], width=6),
            ])
        ])
    ], className="mb-4 shadow-sm border-0"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader("1. Contratti"), dbc.CardBody(dcc.Graph(id='graph-contracts'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader("2. Dettaglio"), dbc.CardBody(dcc.Graph(id='graph-target'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-3'), dbc.CardBody(dcc.Graph(id='trend-contracts-sesso'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-4'), dbc.CardBody(dcc.Graph(id='trend-target-sesso'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-5'), dbc.CardBody(dcc.Graph(id='trend-contracts-evento'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-6'), dbc.CardBody(dcc.Graph(id='trend-target-evento'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-7'), dbc.CardBody(dcc.Graph(id='trend-contracts-naz'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-8'), dbc.CardBody(dcc.Graph(id='trend-target-naz'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-9'), dbc.CardBody(dcc.Graph(id='trend-contracts-cpi'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-10'), dbc.CardBody(dcc.Graph(id='trend-target-cpi'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-11'), dbc.CardBody(dcc.Graph(id='trend-contracts-eta'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-12'), dbc.CardBody(dcc.Graph(id='trend-target-eta'))]), width=6),
    ], className="mb-4"),

    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader("Riepilogo Numerico"), dbc.CardBody(id='table-container')]), width=12)])
], fluid=True)

# --- 3. LOGICA FILTRI E RIFINITURA ---
def get_filtered_df(anno, sesso, evento, naz, cpi, eta):
    dff = df.copy()
    if anno: dff = dff[dff['ANNO_EVENTO'].isin(anno)]
    if sesso: dff = dff[dff['SESSO_LAV'].isin(sesso)]
    if evento: dff = dff[dff['TIPO_EVENTO'].isin(evento)]
    if naz: dff = dff[dff['NAZIONALITA'].isin(naz)]
    if cpi: dff = dff[dff['nome_CPI_sede_lavoro'].isin(cpi)]
    if eta: dff = dff[(dff['ETA_LAV'] >= eta[0]) & (dff['ETA_LAV'] <= eta[1])]
    return dff

def refine_fig_layout(fig):
    titolo_legenda = fig.layout.legend.title.text if fig.layout.legend.title and fig.layout.legend.title.text else None
    
    if titolo_legenda:
        if titolo_legenda in MAPPA_NOMI_VISTE:
            titolo_legenda = MAPPA_NOMI_VISTE[titolo_legenda]
        else:
            titolo_legenda = titolo_legenda.replace('_', ' ')

    for trace in fig.data:
        if trace.hovertemplate:
            for nome_grezzo, nome_bello in MAPPA_NOMI_VISTE.items():
                trace.hovertemplate = trace.hovertemplate.replace(nome_grezzo, nome_bello)
            trace.hovertemplate = trace.hovertemplate.replace('_', ' ')

    fig.update_layout(
        xaxis_title=None,
        yaxis_title=None,
        margin=dict(l=250, r=120, t=60, b=50), 
        legend=dict(
            title_text=titolo_legenda,
            orientation="v",
            yanchor="middle",
            y=0.5,
            xanchor="left",
            x=1.02,
            font=dict(size=10)
        )
    )
    return fig

# --- 4. CALLBACKS ---

@callback(Output('store-contratto-sel', 'data'), Input('graph-contracts', 'clickData'), State('store-contratto-sel', 'data'))
def toggle_c(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(Output('store-target-sel', 'data'), Input('graph-target', 'clickData'), State('store-target-sel', 'data'))
def toggle_t(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(
    [Output('graph-contracts', 'figure'), Output('table-container', 'children')],
    [Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-contratto-sel', 'data')]
)
def update_g1(anno, sesso, evento, naz, cpi, eta, sel_c):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
    
    # 1. Contiamo TUTTE le occorrenze senza scartare nulla
    tutti_conteggi = dff['VIZ'].value_counts()
    
    # 2. Prendiamo solo le prime 24
    top = tutti_conteggi.nlargest(24).reset_index()
    top.columns = ['VIZ', 'count']
    
    # 3. Creiamo la 25esima categoria "Altro" se ci sono più di 24 tipologie
    if len(tutti_conteggi) > 24:
        somma_altre = tutti_conteggi.iloc[24:].sum()
        riga_altro = pd.DataFrame({'VIZ': ['Altre Tipologie'], 'count': [somma_altre]})
        top = pd.concat([top, riga_altro], ignore_index=True)
        
    # Calcolo totale e percentuali per avere il 100% spaccato
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1)
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    colors = ['#e74c3c' if v == sel_c else ('#2c3e50' if sel_c is None else '#bdc3c7') for v in top['VIZ']]
    
    fig = px.bar(top, y='VIZ', x='count', orientation='h', template="plotly_white", text='label_text', title="Distribuzione Contratti (Top 24 + Altro)")
    fig.update_traces(marker_color=colors, textposition=['inside']*3 + ['outside']*(len(top)-3), textfont_color=['white']*3 + ['black']*(len(top)-3))
    fig = refine_fig_layout(fig)
    fig.update_layout(height=700)
    
    try:
        fig.write_html(f"{export_dir}/grafico_1.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_1.png")
        force_utf8(f"{export_dir}/grafico_1.html")
    except Exception as e:
        print(f"Salvataggio fallito per grafico 1: {e}")
        pass
    
    pivot = pd.crosstab(dff['VIZ'], dff['SESSO_LAV'], margins=True).reset_index()
    return fig, dash_table.DataTable(data=pivot.to_dict('records'), columns=[{"name": str(i), "id": str(i)} for i in pivot.columns], page_size=10)

@callback(
    Output('graph-target', 'figure'),
    [Input('store-contratto-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-target-sel', 'data')]
)
def update_g2(sel_c, target_dim, anno, sesso, evento, naz, cpi, eta, sel_t):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    
    if sel_c:
        dff['VIZ_C'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        # Protezione per "Altre Tipologie"
        if sel_c == 'Altre Tipologie':
            top_24_esclusi = dff['VIZ_C'].value_counts().nlargest(24).index
            dff = dff[~dff['VIZ_C'].isin(top_24_esclusi)]
        else:
            dff = dff[dff['VIZ_C'] == sel_c]
    
    top = dff[target_dim].value_counts().nlargest(25).reset_index()
    top.columns = [target_dim, 'count']
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1) if total_count > 0 else 0
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    colors = ['#e74c3c' if v == sel_t else ('#16a085' if sel_t is None else '#bdc3c7') for v in top[target_dim]]
    
    nome_dimensione = "Qualifiche" if target_dim == 'qualifiche_cp2021_5digit' else "Settore ATECO"
    nome_contratto = sel_c if sel_c else "Tutti i contratti"
    titolo_dinamico_g2 = f"Top 25 {nome_dimensione} ({nome_contratto})"

    fig = px.bar(top, y=target_dim, x='count', orientation='h', template="plotly_white", text='label_text', title=titolo_dinamico_g2)
    fig.update_traces(marker_color=colors, textposition=['inside']*3 + ['outside']*(len(top)-3), textfont_color=['white']*3 + ['black']*(len(top)-3))
    fig = refine_fig_layout(fig)
    fig.update_layout(height=700)
    
    try:
        fig.write_html(f"{export_dir}/grafico_2.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_2.png")
        force_utf8(f"{export_dir}/grafico_2.html")
    except Exception as e:
        pass
    
    return fig

@callback(
    [Output('trend-contracts-sesso', 'figure'), Output('trend-contracts-evento', 'figure'),
     Output('trend-contracts-naz', 'figure'), Output('trend-contracts-cpi', 'figure'),
     Output('trend-contracts-eta', 'figure'), 
     Output('title-3', 'children'), Output('title-5', 'children'),
     Output('title-7', 'children'), Output('title-9', 'children'),
     Output('title-11', 'children')], 
    [Input('store-contratto-sel', 'data'), Input('f-anno', 'value'), Input('f-sesso', 'value'), 
     Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_left(sel_c, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    label = sel_c if sel_c else "Tutti i contratti"
    
    if sel_c:
        dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        # Protezione per "Altre Tipologie"
        if sel_c == 'Altre Tipologie':
            top_24_esclusi = dff['VIZ'].value_counts().nlargest(24).index
            dff = dff[~dff['VIZ'].isin(top_24_esclusi)]
        else:
            dff = dff[dff['VIZ'] == sel_c]
    
    f3 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f5 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    
    top_25_naz_left = dff['NAZIONALITA'].value_counts().nlargest(25).index.tolist()
    dff_f7 = dff[dff['NAZIONALITA'].isin(top_25_naz_left)]
    f7 = px.line(dff_f7.groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), 
                 x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, 
                 title=f"Trend Nazionalità: {label}",
                 category_orders={"NAZIONALITA": top_25_naz_left})
    
    f9 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f11 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età ISTAT: {label}")
    
    for idx, f in enumerate([f3, f5, f7, f9, f11]): 
        f = refine_fig_layout(f)
        f.update_layout(xaxis=dict(dtick=1), template="plotly_white")
        num = 3 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except Exception as e:
            pass
            
    return f3, f5, f7, f9, f11, f"3. {label}", f"5. {label}", f"7. {label}", f"9. {label}", f"11. {label}"

@callback(
    [Output('trend-target-sesso', 'figure'), Output('trend-target-evento', 'figure'),
     Output('trend-target-naz', 'figure'), Output('trend-target-cpi', 'figure'),
     Output('trend-target-eta', 'figure'), 
     Output('title-4', 'children'), Output('title-6', 'children'),
     Output('title-8', 'children'), Output('title-10', 'children'),
     Output('title-12', 'children')], 
    [Input('store-target-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_right(sel_t, target_dim, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    
    if sel_t:
        dff = dff[dff[target_dim] == sel_t]
        label = sel_t
    else:
        top_25 = dff[target_dim].value_counts().nlargest(25).index
        dff = dff[dff[target_dim].isin(top_25)]
        label = "Top 25 " + ("Qualifiche" if target_dim == 'qualifiche_cp2021_5digit' else "Settore ATECO")
    
    f4 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f6 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    
    top_25_naz_right = dff['NAZIONALITA'].value_counts().nlargest(25).index.tolist()
    dff_f8 = dff[dff['NAZIONALITA'].isin(top_25_naz_right)]
    f8 = px.line(dff_f8.groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), 
                 x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, 
                 title=f"Trend Nazionalità: {label}",
                 category_orders={"NAZIONALITA": top_25_naz_right})

    f10 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f12 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età ISTAT: {label}")
    
    for idx, f in enumerate([f4, f6, f8, f10, f12]): 
        f = refine_fig_layout(f)
        f.update_layout(xaxis=dict(dtick=1), template="plotly_white")
        num = 4 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except Exception as e:
            pass
            
    return f4, f6, f8, f10, f12, f"4. {label}", f"6. {label}", f"8. {label}", f"10. {label}", f"12. {label}"

if __name__ == '__main__':
    app.run(mode="inline", port=8052)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8052/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html, Input, Output, callback, dash_table, State
import plotly.express as px
import pandas as pd
import dash_bootstrap_components as dbc
import os

# --- 0. PREPARAZIONE CARTELLA ESPORTAZIONE ---
export_dir = os.path.join("..", "esportazioni_quarto") 
if not os.path.exists(export_dir):
    os.makedirs(export_dir)

# --- FUNZIONE: FORZA UTF-8 PER ACCENTI ---
def force_utf8(filepath):
    try:
        if os.path.exists(filepath):
            with open(filepath, 'r', encoding='iso-8859-1') as f:
                content = f.read()
            with open(filepath, 'w', encoding='utf-8') as f:
                f.write(content)
    except Exception as e:
        print(f"Errore force_utf8: {e}")

# --- 1. CONFIGURAZIONE E DATI ---

MAPPA_NOMI_VISTE = {
    'nome_CPI_sede_lavoro': "Centro per l'Impiego",
    'qualifiche_cp2021_5digit': "Qualifica Professionale",
    'ateco2007_DIVISIONE_NOME': "Settore ATECO",
    'SESSO_LAV': "Genere",
    'ETA_LAV_ISTAT': "Fascia d'Età ISTAT",
    'TIPO_EVENTO': "Tipologia Evento",
    'NAZIONALITA': "Nazionalità",
    'ANNO_EVENTO': "Anno"
}

color_map_sesso = {'F': '#e74c3c', 'M': '#3498db'}

# Assicurati che 'df' sia caricato
min_age, max_age = int(df['ETA_LAV'].min()), int(df['ETA_LAV'].max())

def get_options(col_name):
    return [{'label': str(val), 'value': val} for val in sorted(df[col_name].unique())]

# --- 2. LAYOUT ---
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container([
    dcc.Store(id='store-contratto-sel', data=None),
    dcc.Store(id='store-target-sel', data=None),
    
    html.H1('BI: Analisi Mercato del Lavoro', className="mt-3 text-primary fw-bold"),
    html.Hr(),
    
    dbc.Card([
        dbc.CardBody([
            dbc.Row([
                dbc.Col([html.Label("Anno"), dcc.Dropdown(id='f-anno', options=get_options('ANNO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Sesso"), dcc.Dropdown(id='f-sesso', options=get_options('SESSO_LAV'), multi=True)], width=2),
                dbc.Col([html.Label("Tipo Evento"), dcc.Dropdown(id='f-evento', options=get_options('TIPO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Nazionalità"), dcc.Dropdown(id='f-nazionalita', options=get_options('NAZIONALITA'), multi=True)], width=3),
                dbc.Col([html.Label("CPI"), dcc.Dropdown(id='f-cpi', options=get_options('nome_CPI_sede_lavoro'), multi=True)], width=3),
            ], className="mb-3"),
            dbc.Row([
                dbc.Col([
                    html.Label("Analisi Dettaglio:", className="fw-bold text-danger"),
                    dcc.RadioItems(
                        id='target-dimension',
                        options=[{'label': ' Qualifiche', 'value': 'qualifiche_cp2021_5digit'},
                                 {'label': ' Settore ATECO', 'value': 'ateco2007_DIVISIONE_NOME'}],
                        value='qualifiche_cp2021_5digit', inline=True,
                        inputStyle={"margin-left": "20px", "margin-right": "5px"}
                    )
                ], width=6),
                dbc.Col([html.Label("Età"), dcc.RangeSlider(id='f-eta', min=min_age, max=max_age, value=[min_age, max_age])], width=6),
            ])
        ])
    ], className="mb-4 shadow-sm border-0"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader("1. Contratti"), dbc.CardBody(dcc.Graph(id='graph-contracts'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader("2. Dettaglio"), dbc.CardBody(dcc.Graph(id='graph-target'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-3'), dbc.CardBody(dcc.Graph(id='trend-contracts-sesso'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-4'), dbc.CardBody(dcc.Graph(id='trend-target-sesso'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-5'), dbc.CardBody(dcc.Graph(id='trend-contracts-evento'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-6'), dbc.CardBody(dcc.Graph(id='trend-target-evento'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-7'), dbc.CardBody(dcc.Graph(id='trend-contracts-naz'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-8'), dbc.CardBody(dcc.Graph(id='trend-target-naz'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-9'), dbc.CardBody(dcc.Graph(id='trend-contracts-cpi'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-10'), dbc.CardBody(dcc.Graph(id='trend-target-cpi'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-11'), dbc.CardBody(dcc.Graph(id='trend-contracts-eta'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-12'), dbc.CardBody(dcc.Graph(id='trend-target-eta'))]), width=6),
    ], className="mb-4"),

    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader("Riepilogo Numerico"), dbc.CardBody(id='table-container')]), width=12)])
], fluid=True)

# --- 3. LOGICA FILTRI E RIFINITURA ---
def get_filtered_df(anno, sesso, evento, naz, cpi, eta):
    dff = df.copy()
    if anno: dff = dff[dff['ANNO_EVENTO'].isin(anno)]
    if sesso: dff = dff[dff['SESSO_LAV'].isin(sesso)]
    if evento: dff = dff[dff['TIPO_EVENTO'].isin(evento)]
    if naz: dff = dff[dff['NAZIONALITA'].isin(naz)]
    if cpi: dff = dff[dff['nome_CPI_sede_lavoro'].isin(cpi)]
    if eta: dff = dff[(dff['ETA_LAV'] >= eta[0]) & (dff['ETA_LAV'] <= eta[1])]
    return dff

def refine_fig_layout(fig):
    titolo_legenda = fig.layout.legend.title.text if fig.layout.legend.title and fig.layout.legend.title.text else None
    if titolo_legenda:
        if titolo_legenda in MAPPA_NOMI_VISTE:
            titolo_legenda = MAPPA_NOMI_VISTE[titolo_legenda]
        else:
            titolo_legenda = titolo_legenda.replace('_', ' ')

    for trace in fig.data:
        if trace.hovertemplate:
            for nome_grezzo, nome_bello in MAPPA_NOMI_VISTE.items():
                trace.hovertemplate = trace.hovertemplate.replace(nome_grezzo, nome_bello)
            trace.hovertemplate = trace.hovertemplate.replace('_', ' ')

    fig.update_layout(
        xaxis_title=None, yaxis_title=None,
        margin=dict(l=250, r=120, t=60, b=50), 
        legend=dict(
            title_text=titolo_legenda, orientation="v",
            yanchor="middle", y=0.5, xanchor="left", x=1.02,
            font=dict(size=10)
        )
    )
    return fig

# --- 4. CALLBACKS ---

@callback(Output('store-contratto-sel', 'data'), Input('graph-contracts', 'clickData'), State('store-contratto-sel', 'data'))
def toggle_c(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(Output('store-target-sel', 'data'), Input('graph-target', 'clickData'), State('store-target-sel', 'data'))
def toggle_t(click, curr):
    if not click: return None
    # Fondamentale: recuperiamo il valore ORIGINALE dal customdata
    new = click['points'][0]['customdata'][0]
    return None if new == curr else new

@callback(
    [Output('graph-contracts', 'figure'), Output('table-container', 'children')],
    [Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-contratto-sel', 'data')]
)
def update_g1(anno, sesso, evento, naz, cpi, eta, sel_c):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
    
    tutti_conteggi = dff['VIZ'].value_counts()
    top = tutti_conteggi.nlargest(24).reset_index()
    top.columns = ['VIZ', 'count']
    
    if len(tutti_conteggi) > 24:
        somma_altre = tutti_conteggi.iloc[24:].sum()
        riga_altro = pd.DataFrame({'VIZ': ['Altre Tipologie'], 'count': [somma_altre]})
        top = pd.concat([top, riga_altro], ignore_index=True)
        
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1)
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    colors = ['#e74c3c' if v == sel_c else ('#2c3e50' if sel_c is None else '#bdc3c7') for v in top['VIZ']]
    
    fig = px.bar(top, y='VIZ', x='count', orientation='h', template="plotly_white", text='label_text', title="Distribuzione Contratti (Top 24 + Altro)")
    fig.update_traces(marker_color=colors, textposition=['inside']*3 + ['outside']*(len(top)-3), textfont_color=['white']*3 + ['black']*(len(top)-3))
    fig = refine_fig_layout(fig)
    fig.update_layout(height=700)
    
    try:
        fig.write_html(f"{export_dir}/grafico_1.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_1.png")
        force_utf8(f"{export_dir}/grafico_1.html")
    except: pass
    
    pivot = pd.crosstab(dff['VIZ'], dff['SESSO_LAV'], margins=True).reset_index()
    return fig, dash_table.DataTable(data=pivot.to_dict('records'), columns=[{"name": str(i), "id": str(i)} for i in pivot.columns], page_size=10)

@callback(
    Output('graph-target', 'figure'),
    [Input('store-contratto-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-target-sel', 'data')]
)
def update_g2(sel_c, target_dim, anno, sesso, evento, naz, cpi, eta, sel_t):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    
    if sel_c:
        dff['VIZ_C'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        if sel_c == 'Altre Tipologie':
            top_24_esclusi = dff['VIZ_C'].value_counts().nlargest(24).index
            dff = dff[~dff['VIZ_C'].isin(top_24_esclusi)]
        else:
            dff = dff[dff['VIZ_C'] == sel_c]
    
    # Calcolo Top 25
    top = dff[target_dim].value_counts().nlargest(25).reset_index()
    top.columns = [target_dim, 'count']
    
    # --- NUOVA LOGICA: Tronca a 60 per asse Y, ma tieni originale per Tooltip/Filtri ---
    top['VIZ_T'] = top[target_dim].apply(lambda x: (str(x)[:50] + '...') if len(str(x)) > 53 else x)
    
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1) if total_count > 0 else 0
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    # Colori basati sul valore ORIGINALE (target_dim) per coerenza con lo Store
    colors = ['#e74c3c' if v == sel_t else ('#16a085' if sel_t is None else '#bdc3c7') for v in top[target_dim]]
    
    nome_dimensione = "Qualifiche" if target_dim == 'qualifiche_cp2021_5digit' else "Settore ATECO"
    nome_contratto = sel_c if sel_c else "Tutti i contratti"
    titolo_dinamico_g2 = f"Top 25 {nome_dimensione} ({nome_contratto})"

    # Usiamo VIZ_T per la Y, ma passiamo target_dim in custom_data
    fig = px.bar(top, y='VIZ_T', x='count', orientation='h', template="plotly_white", 
                 text='label_text', title=titolo_dinamico_g2, custom_data=[target_dim])
    
    fig.update_traces(
        marker_color=colors, 
        textposition=['inside']*3 + ['outside']*(len(top)-3), 
        textfont_color=['white']*3 + ['black']*(len(top)-3),
        hovertemplate="<b>%{customdata[0]}</b><br>Conteggio: %{x}<extra></extra>" # Tooltip completo
    )
    
    fig = refine_fig_layout(fig)
    fig.update_layout(height=700)
    
    try:
        fig.write_html(f"{export_dir}/grafico_2.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_2.png")
        force_utf8(f"{export_dir}/grafico_2.html")
    except: pass
    
    return fig

@callback(
    [Output('trend-contracts-sesso', 'figure'), Output('trend-contracts-evento', 'figure'),
     Output('trend-contracts-naz', 'figure'), Output('trend-contracts-cpi', 'figure'),
     Output('trend-contracts-eta', 'figure'), 
     Output('title-3', 'children'), Output('title-5', 'children'),
     Output('title-7', 'children'), Output('title-9', 'children'),
     Output('title-11', 'children')], 
    [Input('store-contratto-sel', 'data'), Input('f-anno', 'value'), Input('f-sesso', 'value'), 
     Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_left(sel_c, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    label = sel_c if sel_c else "Tutti i contratti"
    
    if sel_c:
        dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        if sel_c == 'Altre Tipologie':
            top_24_esclusi = dff['VIZ'].value_counts().nlargest(24).index
            dff = dff[~dff['VIZ'].isin(top_24_esclusi)]
        else:
            dff = dff[dff['VIZ'] == sel_c]
    
    f3 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f5 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    
    top_25_naz_left = dff['NAZIONALITA'].value_counts().nlargest(25).index.tolist()
    dff_f7 = dff[dff['NAZIONALITA'].isin(top_25_naz_left)]
    f7 = px.line(dff_f7.groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), 
                 x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, title=f"Trend Nazionalità: {label}")
    
    f9 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f11 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età ISTAT: {label}")
    
    for idx, f in enumerate([f3, f5, f7, f9, f11]): 
        f = refine_fig_layout(f)
        f.update_layout(xaxis=dict(dtick=1), template="plotly_white")
        num = 3 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except: pass
            
    return f3, f5, f7, f9, f11, f"3. {label}", f"5. {label}", f"7. {label}", f"9. {label}", f"11. {label}"

@callback(
    [Output('trend-target-sesso', 'figure'), Output('trend-target-evento', 'figure'),
     Output('trend-target-naz', 'figure'), Output('trend-target-cpi', 'figure'),
     Output('trend-target-eta', 'figure'), 
     Output('title-4', 'children'), Output('title-6', 'children'),
     Output('title-8', 'children'), Output('title-10', 'children'),
     Output('title-12', 'children')], 
    [Input('store-target-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_right(sel_t, target_dim, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    
    if sel_t:
        dff = dff[dff[target_dim] == sel_t]
        label = sel_t
    else:
        top_25 = dff[target_dim].value_counts().nlargest(25).index
        dff = dff[dff[target_dim].isin(top_25)]
        label = "Top 25 " + ("Qualifiche" if target_dim == 'qualifiche_cp2021_5digit' else "Settore ATECO")
    
    f4 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f6 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    
    top_25_naz_right = dff['NAZIONALITA'].value_counts().nlargest(25).index.tolist()
    dff_f8 = dff[dff['NAZIONALITA'].isin(top_25_naz_right)]
    f8 = px.line(dff_f8.groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), 
                 x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, title=f"Trend Nazionalità: {label}")

    f10 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f12 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età ISTAT: {label}")
    
    for idx, f in enumerate([f4, f6, f8, f10, f12]): 
        f = refine_fig_layout(f)
        f.update_layout(xaxis=dict(dtick=1), template="plotly_white")
        num = 4 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except: pass
            
    return f4, f6, f8, f10, f12, f"4. {label}", f"6. {label}", f"8. {label}", f"10. {label}", f"12. {label}"

if __name__ == '__main__':
    app.run(mode="inline", port=8053)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8053/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html, Input, Output, callback, dash_table, State
import plotly.express as px
import pandas as pd
import dash_bootstrap_components as dbc
import os

# --- 0. PREPARAZIONE CARTELLA ESPORTAZIONE ---
export_dir = os.path.join("..", "esportazioni_quarto") 
if not os.path.exists(export_dir):
    os.makedirs(export_dir)

# --- FUNZIONE: FORZA UTF-8 PER ACCENTI ---
def force_utf8(filepath):
    try:
        if os.path.exists(filepath):
            with open(filepath, 'r', encoding='iso-8859-1') as f:
                content = f.read()
            with open(filepath, 'w', encoding='utf-8') as f:
                f.write(content)
    except Exception as e:
        print(f"Errore force_utf8: {e}")

# --- 1. CONFIGURAZIONE E DATI ---

MAPPA_NOMI_VISTE = {
    'nome_CPI_sede_lavoro': "Centro per l'Impiego",
    'qualifiche_cp2021_5digit': "Qualifica Professionale",
    'ateco2007_DIVISIONE_NOME': "Settore ATECO",
    'SESSO_LAV': "Genere",
    'ETA_LAV_ISTAT': "Fascia d'Età ISTAT",
    'TIPO_EVENTO': "Tipologia Evento",
    'NAZIONALITA': "Nazionalità",
    'ANNO_EVENTO': "Anno"
}

color_map_sesso = {'F': '#e74c3c', 'M': '#3498db'}

# Assicurati che 'df' sia caricato correttamente qui sopra
min_age, max_age = int(df['ETA_LAV'].min()), int(df['ETA_LAV'].max())

def get_options(col_name):
    return [{'label': str(val), 'value': val} for val in sorted(df[col_name].unique())]

# --- 3. LOGICA DI RIFINITURA ESTETICA ---

def refine_fig_layout(fig, is_trend=False):
    titolo_legenda = fig.layout.legend.title.text if fig.layout.legend.title and fig.layout.legend.title.text else None
    if titolo_legenda:
        titolo_legenda = MAPPA_NOMI_VISTE.get(titolo_legenda, titolo_legenda.replace('_', ' '))

    for trace in fig.data:
        if trace.hovertemplate:
            for nome_grezzo, nome_bello in MAPPA_NOMI_VISTE.items():
                trace.hovertemplate = trace.hovertemplate.replace(nome_grezzo, nome_bello)
            trace.hovertemplate = trace.hovertemplate.replace('_', ' ')

    if is_trend:
        m_left, m_right, h_pref = 60, 50, 400
    else:
        m_left, m_right, h_pref = 220, 120, 750

    fig.update_layout(
        xaxis_title=None, yaxis_title=None, height=h_pref,
        margin=dict(l=m_left, r=m_right, t=60, b=50),
        paper_bgcolor='white', plot_bgcolor='white',
        xaxis=dict(showgrid=True, gridcolor='rgba(235, 235, 235, 1)', zeroline=False),
        yaxis=dict(showgrid=True, gridcolor='rgba(235, 235, 235, 1)', zeroline=False),
        legend=dict(title_text=titolo_legenda, orientation="v", yanchor="middle", y=0.5, xanchor="left", x=1.02, font=dict(size=10)),
        template="plotly_white"
    )
    return fig

# --- 2. LAYOUT DASH ---

app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container([
    dcc.Store(id='store-contratto-sel', data=None),
    dcc.Store(id='store-target-sel', data=None),
    html.H1('BI: Analisi Mercato del Lavoro', className="mt-3 text-primary fw-bold"),
    html.Hr(),
    dbc.Card([
        dbc.CardBody([
            dbc.Row([
                dbc.Col([html.Label("Anno"), dcc.Dropdown(id='f-anno', options=get_options('ANNO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Sesso"), dcc.Dropdown(id='f-sesso', options=get_options('SESSO_LAV'), multi=True)], width=2),
                dbc.Col([html.Label("Tipo Evento"), dcc.Dropdown(id='f-evento', options=get_options('TIPO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Nazionalità"), dcc.Dropdown(id='f-nazionalita', options=get_options('NAZIONALITA'), multi=True)], width=3),
                dbc.Col([html.Label("CPI"), dcc.Dropdown(id='f-cpi', options=get_options('nome_CPI_sede_lavoro'), multi=True)], width=3),
            ], className="mb-3"),
            dbc.Row([
                dbc.Col([
                    html.Label("Analisi Dettaglio:", className="fw-bold text-danger"),
                    dcc.RadioItems(
                        id='target-dimension',
                        options=[{'label': ' Qualifiche', 'value': 'qualifiche_cp2021_5digit'},
                                 {'label': ' Settore ATECO', 'value': 'ateco2007_DIVISIONE_NOME'}],
                        value='qualifiche_cp2021_5digit', inline=True,
                        inputStyle={"margin-left": "20px", "margin-right": "5px"}
                    )
                ], width=6),
                dbc.Col([html.Label("Età"), dcc.RangeSlider(id='f-eta', min=min_age, max=max_age, value=[min_age, max_age])], width=6),
            ])
        ])
    ], className="mb-4 shadow-sm border-0"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader("1. Contratti"), dbc.CardBody(dcc.Graph(id='graph-contracts'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader("2. Dettaglio"), dbc.CardBody(dcc.Graph(id='graph-target'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-3'), dbc.CardBody(dcc.Graph(id='trend-contracts-sesso'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-4'), dbc.CardBody(dcc.Graph(id='trend-target-sesso'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-5'), dbc.CardBody(dcc.Graph(id='trend-contracts-evento'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-6'), dbc.CardBody(dcc.Graph(id='trend-target-evento'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-7'), dbc.CardBody(dcc.Graph(id='trend-contracts-naz'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-8'), dbc.CardBody(dcc.Graph(id='trend-target-naz'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-9'), dbc.CardBody(dcc.Graph(id='trend-contracts-cpi'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-10'), dbc.CardBody(dcc.Graph(id='trend-target-cpi'))]), width=6),
    ], className="mb-4"),

    dbc.Row([
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-11'), dbc.CardBody(dcc.Graph(id='trend-contracts-eta'))]), width=6),
        dbc.Col(dbc.Card([dbc.CardHeader(id='title-12'), dbc.CardBody(dcc.Graph(id='trend-target-eta'))]), width=6),
    ], className="mb-4"),

    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader("Riepilogo Numerico"), dbc.CardBody(id='table-container')]), width=12)])
], fluid=True)

def get_filtered_df(anno, sesso, evento, naz, cpi, eta):
    dff = df.copy()
    if anno: dff = dff[dff['ANNO_EVENTO'].isin(anno)]
    if sesso: dff = dff[dff['SESSO_LAV'].isin(sesso)]
    if evento: dff = dff[dff['TIPO_EVENTO'].isin(evento)]
    if naz: dff = dff[dff['NAZIONALITA'].isin(naz)]
    if cpi: dff = dff[dff['nome_CPI_sede_lavoro'].isin(cpi)]
    if eta: dff = dff[(dff['ETA_LAV'] >= eta[0]) & (dff['ETA_LAV'] <= eta[1])]
    return dff

# --- CALLBACKS ---

@callback(Output('store-contratto-sel', 'data'), Input('graph-contracts', 'clickData'), State('store-contratto-sel', 'data'))
def toggle_c(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(Output('store-target-sel', 'data'), Input('graph-target', 'clickData'), State('store-target-sel', 'data'))
def toggle_t(click, curr):
    if not click: return None
    new = click['points'][0]['customdata'][0]
    return None if new == curr else new

@callback(
    [Output('graph-contracts', 'figure'), Output('table-container', 'children')],
    [Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-contratto-sel', 'data')]
)
def update_g1(anno, sesso, evento, naz, cpi, eta, sel_c):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
    tutti_conteggi = dff['VIZ'].value_counts()
    top = tutti_conteggi.nlargest(24).reset_index()
    top.columns = ['VIZ', 'count']
    if len(tutti_conteggi) > 24:
        somma_altre = tutti_conteggi.iloc[24:].sum()
        top = pd.concat([top, pd.DataFrame({'VIZ': ['Altre Tipologie'], 'count': [somma_altre]})], ignore_index=True)
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1)
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    colors = ['#e74c3c' if v == sel_c else ('#2c3e50' if sel_c is None else '#bdc3c7') for v in top['VIZ']]
    fig = px.bar(top, y='VIZ', x='count', orientation='h', template="plotly_white", text='label_text', title="Distribuzione Contratti")
    fig.update_traces(marker_color=colors, textposition='auto')
    fig = refine_fig_layout(fig, is_trend=False)
    try:
        fig.write_html(f"{export_dir}/grafico_1.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_1.png")
        force_utf8(f"{export_dir}/grafico_1.html")
    except: pass
    pivot = pd.crosstab(dff['VIZ'], dff['SESSO_LAV'], margins=True).reset_index()
    return fig, dash_table.DataTable(data=pivot.to_dict('records'), page_size=10)

@callback(
    Output('graph-target', 'figure'),
    [Input('store-contratto-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-target-sel', 'data')]
)
def update_g2(sel_c, target_dim, anno, sesso, evento, naz, cpi, eta, sel_t):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    if sel_c:
        dff['VIZ_C'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        if sel_c == 'Altre Tipologie':
            top_24_esclusi = dff['VIZ_C'].value_counts().nlargest(24).index
            dff = dff[~dff['VIZ_C'].isin(top_24_esclusi)]
        else:
            dff = dff[dff['VIZ_C'] == sel_c]
    top = dff[target_dim].value_counts().nlargest(25).reset_index()
    top.columns = [target_dim, 'count']
    top['VIZ_T'] = top[target_dim].apply(lambda x: (str(x)[:50] + '...') if len(str(x)) > 53 else x)
    total_count = top['count'].sum()
    top['percentage'] = (top['count'] / total_count * 100).round(1) if total_count > 0 else 0
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    colors = ['#e74c3c' if v == sel_t else ('#16a085' if sel_t is None else '#bdc3c7') for v in top[target_dim]]
    fig = px.bar(top, y='VIZ_T', x='count', orientation='h', template="plotly_white", 
                 text='label_text', title=f"Dettaglio {MAPPA_NOMI_VISTE.get(target_dim)}", custom_data=[target_dim])
    fig.update_traces(marker_color=colors, textposition='auto', hovertemplate="<b>%{customdata[0]}</b><br>Conteggio: %{x}<extra></extra>")
    fig = refine_fig_layout(fig, is_trend=False)
    try:
        fig.write_html(f"{export_dir}/grafico_2.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_2.png")
        force_utf8(f"{export_dir}/grafico_2.html")
    except: pass
    return fig

@callback(
    [Output('trend-contracts-sesso', 'figure'), Output('trend-contracts-evento', 'figure'),
     Output('trend-contracts-naz', 'figure'), Output('trend-contracts-cpi', 'figure'),
     Output('trend-contracts-eta', 'figure'), 
     Output('title-3', 'children'), Output('title-5', 'children'),
     Output('title-7', 'children'), Output('title-9', 'children'),
     Output('title-11', 'children')], 
    [Input('store-contratto-sel', 'data'), Input('f-anno', 'value'), Input('f-sesso', 'value'), 
     Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_left(sel_c, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    label = sel_c if sel_c else "Tutti i contratti"
    if sel_c:
        dff['VIZ_C'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        if sel_c == 'Altre Tipologie':
            top_24_esclusi = dff['VIZ_C'].value_counts().nlargest(24).index
            dff = dff[~dff['VIZ_C'].isin(top_24_esclusi)]
        else:
            dff = dff[dff['VIZ_C'] == sel_c]
    
    # TITOLI DINAMICI PER LA COLONNA SINISTRA
    f3 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f5 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    top_naz = dff['NAZIONALITA'].value_counts().nlargest(10).index.tolist()
    f7 = px.line(dff[dff['NAZIONALITA'].isin(top_naz)].groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, title=f"Trend Nazionalità: {label}")
    f9 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f11 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età: {label}")
    
    for idx, f in enumerate([f3, f5, f7, f9, f11]): 
        f = refine_fig_layout(f, is_trend=True)
        f.update_layout(xaxis=dict(dtick=1))
        num = 3 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except: pass
    return f3, f5, f7, f9, f11, f"3. {label}", f"5. {label}", f"7. {label}", f"9. {label}", f"11. {label}"

@callback(
    [Output('trend-target-sesso', 'figure'), Output('trend-target-evento', 'figure'),
     Output('trend-target-naz', 'figure'), Output('trend-target-cpi', 'figure'),
     Output('trend-target-eta', 'figure'), 
     Output('title-4', 'children'), Output('title-6', 'children'),
     Output('title-8', 'children'), Output('title-10', 'children'),
     Output('title-12', 'children')], 
    [Input('store-target-sel', 'data'), Input('target-dimension', 'value'),
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')]
)
def update_t_right(sel_t, target_dim, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    dim_bello = MAPPA_NOMI_VISTE.get(target_dim, target_dim)
    if sel_t:
        dff = dff[dff[target_dim] == sel_t]
        label = sel_t
    else:
        top_25 = dff[target_dim].value_counts().nlargest(25).index
        dff = dff[dff[target_dim].isin(top_25)]
        label = f"Top 25 {dim_bello}"
    
    # TITOLI DINAMICI PER LA COLONNA DESTRA
    f4 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f6 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    top_naz = dff['NAZIONALITA'].value_counts().nlargest(10).index.tolist()
    f8 = px.line(dff[dff['NAZIONALITA'].isin(top_naz)].groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, title=f"Trend Nazionalità: {label}")
    f10 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f12 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età: {label}")
    
    for idx, f in enumerate([f4, f6, f8, f10, f12]): 
        f = refine_fig_layout(f, is_trend=True)
        f.update_layout(xaxis=dict(dtick=1))
        num = 4 + (idx * 2)
        try:
            f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
            f.write_image(f"{export_dir}/grafico_{num}.png")
            force_utf8(f"{export_dir}/grafico_{num}.html")
        except: pass
    return f4, f6, f8, f10, f12, f"4. {label}", f"6. {label}", f"8. {label}", f"10. {label}", f"12. {label}"

if __name__ == '__main__':
    app.run(mode="inline", port=8054)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8054/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html, Input, Output, callback, dash_table, State
import plotly.express as px
import pandas as pd
import dash_bootstrap_components as dbc
import os

# --- 0. PREPARAZIONE CARTELLA ESPORTAZIONE ---
export_dir = os.path.join("..", "esportazioni_quarto") 
if not os.path.exists(export_dir):
    os.makedirs(export_dir)

def force_utf8(filepath):
    try:
        if os.path.exists(filepath):
            with open(filepath, 'r', encoding='iso-8859-1') as f:
                content = f.read()
            with open(filepath, 'w', encoding='utf-8') as f:
                f.write(content)
    except:
        pass

# --- 1. CONFIGURAZIONE E DATI ---
MAPPA_NOMI_VISTE = {
    'nome_CPI_sede_lavoro': "Centro per l'Impiego",
    'qualifiche_cp2021_5digit': "Qualifica Professionale",
    'ateco2007_DIVISIONE_NOME': "Settore ATECO",
    'SESSO_LAV': "Genere",
    'ETA_LAV_ISTAT': "Fascia d'Età ISTAT",
    'TIPO_EVENTO': "Tipologia Evento",
    'NAZIONALITA': "Nazionalità",
    'ANNO_EVENTO': "Anno"
}

color_map_sesso = {'F': '#e74c3c', 'M': '#3498db'}

# Assumendo che df sia già caricato nel namespace
min_age, max_age = int(df['ETA_LAV'].min()), int(df['ETA_LAV'].max())

def get_options(col_name):
    options = [{'label': str(val), 'value': val} for val in sorted(df[col_name].unique())]
    if col_name == 'NAZIONALITA':
        special_options = [
            {'label': '-- SELEZIONA LE 10 PIÙ NUMEROSE --', 'value': 'TOP_10'},
            {'label': '-- SELEZIONA LE 25 PIÙ NUMEROSE --', 'value': 'TOP_25'}
        ]
        return special_options + options
    return options

def refine_fig_layout(fig, is_trend=False):
    titolo_legenda = fig.layout.legend.title.text if fig.layout.legend.title and fig.layout.legend.title.text else None
    if titolo_legenda:
        titolo_legenda = MAPPA_NOMI_VISTE.get(titolo_legenda, titolo_legenda.replace('_', ' '))

    for trace in fig.data:
        if trace.hovertemplate:
            for nome_grezzo, nome_bello in MAPPA_NOMI_VISTE.items():
                trace.hovertemplate = trace.hovertemplate.replace(nome_grezzo, nome_bello)
            trace.hovertemplate = trace.hovertemplate.replace('_', ' ')

    # Configurazione spaziale: l=80 per i trend per garantire allineamento verticale
    m_left, m_right, h_pref = (80, 50, 400) if is_trend else (220, 120, 750)

    fig.update_layout(
        xaxis_title=None, yaxis_title=None, height=h_pref,
        margin=dict(l=m_left, r=m_right, t=60, b=50),
        paper_bgcolor='white', plot_bgcolor='white',
        xaxis=dict(showgrid=True, gridcolor='rgba(235, 235, 235, 1)', zeroline=False),
        yaxis=dict(showgrid=True, gridcolor='rgba(235, 235, 235, 1)', zeroline=False),
        legend=dict(title_text=titolo_legenda, orientation="v", yanchor="middle", y=0.5, xanchor="left", x=1.02, font=dict(size=10)),
        template="plotly_white"
    )
    return fig

# --- 2. LAYOUT ---
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container([
    dcc.Store(id='store-contratto-sel', data=None),
    dcc.Store(id='store-target-sel', data=None),
    html.H1('BI: Analisi Mercato del Lavoro', className="mt-3 text-primary fw-bold"),
    html.Hr(),
    dbc.Card([
        dbc.CardBody([
            dbc.Row([
                dbc.Col([html.Label("Anno"), dcc.Dropdown(id='f-anno', options=get_options('ANNO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Sesso"), dcc.Dropdown(id='f-sesso', options=get_options('SESSO_LAV'), multi=True)], width=2),
                dbc.Col([html.Label("Tipo Evento"), dcc.Dropdown(id='f-evento', options=get_options('TIPO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Nazionalità"), dcc.Dropdown(id='f-nazionalita', options=get_options('NAZIONALITA'), multi=True)], width=3),
                dbc.Col([html.Label("CPI"), dcc.Dropdown(id='f-cpi', options=get_options('nome_CPI_sede_lavoro'), multi=True)], width=3),
            ], className="mb-3"),
            dbc.Row([
                dbc.Col([
                    html.Label("Analisi Dettaglio:", className="fw-bold text-danger"),
                    dcc.RadioItems(id='target-dimension', options=[{'label': ' Qualifiche', 'value': 'qualifiche_cp2021_5digit'}, {'label': ' Settore ATECO', 'value': 'ateco2007_DIVISIONE_NOME'}], value='qualifiche_cp2021_5digit', inline=True)
                ], width=6),
                dbc.Col([html.Label("Età"), dcc.RangeSlider(id='f-eta', min=min_age, max=max_age, value=[min_age, max_age])], width=6),
            ])
        ])
    ], className="mb-4 shadow-sm border-0"),

    # Griglia Grafici
    dbc.Row([dbc.Col(id='card-1', children=dbc.Card([dbc.CardHeader("1. Contratti"), dbc.CardBody(dcc.Graph(id='graph-contracts'))]), width=6),
             dbc.Col(id='card-2', children=dbc.Card([dbc.CardHeader("2. Dettaglio"), dbc.CardBody(dcc.Graph(id='graph-target'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-3'), dbc.CardBody(dcc.Graph(id='trend-contracts-sesso'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-4'), dbc.CardBody(dcc.Graph(id='trend-target-sesso'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-5'), dbc.CardBody(dcc.Graph(id='trend-contracts-evento'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-6'), dbc.CardBody(dcc.Graph(id='trend-target-evento'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-7'), dbc.CardBody(dcc.Graph(id='trend-contracts-naz'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-8'), dbc.CardBody(dcc.Graph(id='trend-target-naz'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-9'), dbc.CardBody(dcc.Graph(id='trend-contracts-cpi'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-10'), dbc.CardBody(dcc.Graph(id='trend-target-cpi'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-11'), dbc.CardBody(dcc.Graph(id='trend-contracts-eta'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-12'), dbc.CardBody(dcc.Graph(id='trend-target-eta'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader("Riepilogo Numerico"), dbc.CardBody(id='table-container')]), width=12)])
], fluid=True)

# --- 3. LOGICA FILTRI ---
def get_filtered_df(anno, sesso, evento, naz, cpi, eta):
    dff = df.copy()
    if anno: dff = dff[dff['ANNO_EVENTO'].isin(anno)]
    if sesso: dff = dff[dff['SESSO_LAV'].isin(sesso)]
    if evento: dff = dff[dff['TIPO_EVENTO'].isin(evento)]
    if naz:
        if 'TOP_10' in naz or 'TOP_25' in naz:
            n = 10 if 'TOP_10' in naz else 25
            top_list = df['NAZIONALITA'].value_counts().nlargest(n).index.tolist()
            dff = dff[dff['NAZIONALITA'].isin(top_list)]
        else:
            dff = dff[dff['NAZIONALITA'].isin(naz)]
    if cpi: dff = dff[dff['nome_CPI_sede_lavoro'].isin(cpi)]
    if eta: dff = dff[(dff['ETA_LAV'] >= eta[0]) & (dff['ETA_LAV'] <= eta[1])]
    return dff

# --- 4. CALLBACKS ---

@callback(Output('store-contratto-sel', 'data'), Input('graph-contracts', 'clickData'), State('store-contratto-sel', 'data'))
def toggle_c(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(Output('store-target-sel', 'data'), Input('graph-target', 'clickData'), State('store-target-sel', 'data'))
def toggle_t(click, curr):
    if not click: return None
    val = click['points'][0]['customdata'][0]
    return None if val == curr else val

@callback([Output('graph-contracts', 'figure'), Output('table-container', 'children')], 
          [Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-contratto-sel', 'data')])
def update_g1(anno, sesso, evento, naz, cpi, eta, sel_c):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
    counts = dff['VIZ'].value_counts()
    top = counts.nlargest(24).reset_index()
    top.columns = ['VIZ', 'count']
    if len(counts) > 24:
        top = pd.concat([top, pd.DataFrame({'VIZ': ['Altre Tipologie'], 'count': [counts.iloc[24:].sum()]})], ignore_index=True)
    top['percentage'] = (top['count'] / top['count'].sum() * 100).round(1)
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    fig = px.bar(top, y='VIZ', x='count', orientation='h', template="plotly_white", text='label_text', title="Distribuzione Contratti")
    fig.update_traces(marker_color=['#e74c3c' if v == sel_c else ('#2c3e50' if sel_c is None else '#bdc3c7') for v in top['VIZ']], textposition='auto')
    fig = refine_fig_layout(fig, is_trend=False)
    
    fig.write_html(f"{export_dir}/grafico_1.html", include_plotlyjs='cdn')
    fig.write_image(f"{export_dir}/grafico_1.png")
    force_utf8(f"{export_dir}/grafico_1.html")
    
    pivot = pd.crosstab(dff['VIZ'], dff['SESSO_LAV'], margins=True).reset_index()
    return fig, dash_table.DataTable(data=pivot.to_dict('records'), page_size=10)

@callback(Output('graph-target', 'figure'), 
          [Input('store-contratto-sel', 'data'), Input('target-dimension', 'value'), Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-target-sel', 'data')])
def update_g2(sel_c, target_dim, anno, sesso, evento, naz, cpi, eta, sel_t):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    if sel_c:
        dff['VIZ_C'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        dff = dff[dff['VIZ_C'] == sel_c] if sel_c != 'Altre Tipologie' else dff[~dff['VIZ_C'].isin(dff['VIZ_C'].value_counts().nlargest(24).index)]
    
    top = dff[target_dim].value_counts().nlargest(25).reset_index()
    top.columns = [target_dim, 'count']
    top['VIZ_T'] = top[target_dim].apply(lambda x: (str(x)[:50] + '...') if len(str(x)) > 53 else x)
    
    fig = px.bar(top, y='VIZ_T', x='count', orientation='h', template="plotly_white", title=f"Dettaglio {MAPPA_NOMI_VISTE.get(target_dim)}", custom_data=[target_dim])
    fig.update_traces(marker_color=['#e74c3c' if v == sel_t else ('#16a085' if sel_t is None else '#bdc3c7') for v in top[target_dim]], textposition='auto')
    fig = refine_fig_layout(fig, is_trend=False)
    
    fig.write_html(f"{export_dir}/grafico_2.html", include_plotlyjs='cdn')
    fig.write_image(f"{export_dir}/grafico_2.png")
    force_utf8(f"{export_dir}/grafico_2.html")
    return fig

@callback([Output('trend-contracts-sesso', 'figure'), Output('trend-contracts-evento', 'figure'), Output('trend-contracts-naz', 'figure'), Output('trend-contracts-cpi', 'figure'), Output('trend-contracts-eta', 'figure'), 
           Output('title-3', 'children'), Output('title-5', 'children'), Output('title-7', 'children'), Output('title-9', 'children'), Output('title-11', 'children')], 
          [Input('store-contratto-sel', 'data'), Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')])
def update_t_left(sel_c, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    label = sel_c if sel_c else "Tutti i contratti"
    
    n_view = 25 if (naz and 'TOP_25' in naz) else 10
    
    f3 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f5 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    f7 = px.line(dff[dff['NAZIONALITA'].isin(dff['NAZIONALITA'].value_counts().nlargest(n_view).index)].groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, title=f"Trend Top {n_view} Nazionalità: {label}")
    f9 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f11 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età: {label}")
    
    for idx, f in enumerate([f3, f5, f7, f9, f11]):
        f = refine_fig_layout(f, is_trend=True)
        num = 3 + (idx * 2)
        f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
        f.write_image(f"{export_dir}/grafico_{num}.png")
        force_utf8(f"{export_dir}/grafico_{num}.html")
        
    return f3, f5, f7, f9, f11, f"3. {label}", f"5. {label}", f"7. {label}", f"9. {label}", f"11. {label}"

@callback([Output('trend-target-sesso', 'figure'), Output('trend-target-evento', 'figure'), Output('trend-target-naz', 'figure'), Output('trend-target-cpi', 'figure'), Output('trend-target-eta', 'figure'), 
           Output('title-4', 'children'), Output('title-6', 'children'), Output('title-8', 'children'), Output('title-10', 'children'), Output('title-12', 'children')], 
          [Input('store-target-sel', 'data'), Input('target-dimension', 'value'), Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')])
def update_t_right(sel_t, target_dim, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    label = sel_t if sel_t else f"Top 25 {MAPPA_NOMI_VISTE.get(target_dim)}"
    if sel_t: dff = dff[dff[target_dim] == sel_t]
    
    n_view = 25 if (naz and 'TOP_25' in naz) else 10
    
    f4 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f6 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    f8 = px.line(dff[dff['NAZIONALITA'].isin(dff['NAZIONALITA'].value_counts().nlargest(n_view).index)].groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, title=f"Trend Top {n_view} Nazionalità: {label}")
    f10 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f12 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età: {label}")
    
    for idx, f in enumerate([f4, f6, f8, f10, f12]):
        f = refine_fig_layout(f, is_trend=True)
        num = 4 + (idx * 2)
        f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
        f.write_image(f"{export_dir}/grafico_{num}.png")
        force_utf8(f"{export_dir}/grafico_{num}.html")
        
    return f4, f6, f8, f10, f12, f"4. {label}", f"6. {label}", f"8. {label}", f"10. {label}", f"12. {label}"

if __name__ == '__main__':
    app.run(mode="inline", port=8055)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8055/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html, Input, Output, callback, dash_table, State
import plotly.express as px
import pandas as pd
import dash_bootstrap_components as dbc
import os

# --- 0. PREPARAZIONE CARTELLA ESPORTAZIONE ---
export_dir = os.path.join("..", "esportazioni_quarto") 
if not os.path.exists(export_dir):
    os.makedirs(export_dir)

def force_utf8(filepath):
    try:
        if os.path.exists(filepath):
            with open(filepath, 'r', encoding='iso-8859-1') as f:
                content = f.read()
            with open(filepath, 'w', encoding='utf-8') as f:
                f.write(content)
    except:
        pass

# --- 1. CONFIGURAZIONE E DATI ---
MAPPA_NOMI_VISTE = {
    'nome_CPI_sede_lavoro': "Centro per l'Impiego",
    'qualifiche_cp2021_5digit': "Qualifica Professionale",
    'ateco2007_DIVISIONE_NOME': "Settore ATECO",
    'SESSO_LAV': "Genere",
    'ETA_LAV_ISTAT': "Fascia d'Età ISTAT",
    'TIPO_EVENTO': "Tipologia Evento",
    'NAZIONALITA': "Nazionalità",
    'ANNO_EVENTO': "Anno"
}

color_map_sesso = {'F': '#e74c3c', 'M': '#3498db'}

# Assumendo che df sia già caricato nel namespace
min_age, max_age = int(df['ETA_LAV'].min()), int(df['ETA_LAV'].max())

def get_options(col_name):
    options = [{'label': str(val), 'value': val} for val in sorted(df[col_name].unique())]
    if col_name == 'NAZIONALITA':
        special_options = [
            {'label': '-- SELEZIONA LE 10 PIÙ NUMEROSE --', 'value': 'TOP_10'},
            {'label': '-- SELEZIONA LE 25 PIÙ NUMEROSE --', 'value': 'TOP_25'}
        ]
        return special_options + options
    return options

def refine_fig_layout(fig, is_trend=False):
    titolo_legenda = fig.layout.legend.title.text if fig.layout.legend.title and fig.layout.legend.title.text else None
    if titolo_legenda:
        titolo_legenda = MAPPA_NOMI_VISTE.get(titolo_legenda, titolo_legenda.replace('_', ' '))

    for trace in fig.data:
        if trace.hovertemplate:
            for nome_grezzo, nome_bello in MAPPA_NOMI_VISTE.items():
                trace.hovertemplate = trace.hovertemplate.replace(nome_grezzo, nome_bello)
            trace.hovertemplate = trace.hovertemplate.replace('_', ' ')

    # Configurazione spaziale: l=80 per i trend per garantire allineamento verticale
    m_left, m_right, h_pref = (80, 50, 400) if is_trend else (220, 120, 750)

    fig.update_layout(
        xaxis_title=None, yaxis_title=None, height=h_pref,
        margin=dict(l=m_left, r=m_right, t=60, b=50),
        paper_bgcolor='white', plot_bgcolor='white',
        xaxis=dict(showgrid=True, gridcolor='rgba(235, 235, 235, 1)', zeroline=False),
        yaxis=dict(showgrid=True, gridcolor='rgba(235, 235, 235, 1)', zeroline=False),
        legend=dict(title_text=titolo_legenda, orientation="v", yanchor="middle", y=0.5, xanchor="left", x=1.02, font=dict(size=10)),
        template="plotly_white"
    )
    return fig

# --- 2. LAYOUT ---
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

app.layout = dbc.Container([
    dcc.Store(id='store-contratto-sel', data=None),
    dcc.Store(id='store-target-sel', data=None),
    html.H1('BI: Analisi Mercato del Lavoro', className="mt-3 text-primary fw-bold"),
    html.Hr(),
    dbc.Card([
        dbc.CardBody([
            dbc.Row([
                dbc.Col([html.Label("Anno"), dcc.Dropdown(id='f-anno', options=get_options('ANNO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Sesso"), dcc.Dropdown(id='f-sesso', options=get_options('SESSO_LAV'), multi=True)], width=2),
                dbc.Col([html.Label("Tipo Evento"), dcc.Dropdown(id='f-evento', options=get_options('TIPO_EVENTO'), multi=True)], width=2),
                dbc.Col([html.Label("Nazionalità"), dcc.Dropdown(id='f-nazionalita', options=get_options('NAZIONALITA'), multi=True)], width=3),
                dbc.Col([html.Label("CPI"), dcc.Dropdown(id='f-cpi', options=get_options('nome_CPI_sede_lavoro'), multi=True)], width=3),
            ], className="mb-3"),
            dbc.Row([
                dbc.Col([
                    html.Label("Analisi Dettaglio:", className="fw-bold text-danger"),
                    dcc.RadioItems(id='target-dimension', options=[{'label': ' Qualifiche', 'value': 'qualifiche_cp2021_5digit'}, {'label': ' Settore ATECO', 'value': 'ateco2007_DIVISIONE_NOME'}], value='qualifiche_cp2021_5digit', inline=True)
                ], width=6),
                dbc.Col([html.Label("Età"), dcc.RangeSlider(id='f-eta', min=min_age, max=max_age, value=[min_age, max_age])], width=6),
            ])
        ])
    ], className="mb-4 shadow-sm border-0"),

    # Griglia Grafici
    dbc.Row([dbc.Col(id='card-1', children=dbc.Card([dbc.CardHeader("1. Contratti"), dbc.CardBody(dcc.Graph(id='graph-contracts'))]), width=6),
             dbc.Col(id='card-2', children=dbc.Card([dbc.CardHeader("2. Dettaglio"), dbc.CardBody(dcc.Graph(id='graph-target'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-3'), dbc.CardBody(dcc.Graph(id='trend-contracts-sesso'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-4'), dbc.CardBody(dcc.Graph(id='trend-target-sesso'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-5'), dbc.CardBody(dcc.Graph(id='trend-contracts-evento'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-6'), dbc.CardBody(dcc.Graph(id='trend-target-evento'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-7'), dbc.CardBody(dcc.Graph(id='trend-contracts-naz'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-8'), dbc.CardBody(dcc.Graph(id='trend-target-naz'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-9'), dbc.CardBody(dcc.Graph(id='trend-contracts-cpi'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-10'), dbc.CardBody(dcc.Graph(id='trend-target-cpi'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader(id='title-11'), dbc.CardBody(dcc.Graph(id='trend-contracts-eta'))]), width=6),
             dbc.Col(dbc.Card([dbc.CardHeader(id='title-12'), dbc.CardBody(dcc.Graph(id='trend-target-eta'))]), width=6)]),
    dbc.Row([dbc.Col(dbc.Card([dbc.CardHeader("Riepilogo Numerico"), dbc.CardBody(id='table-container')]), width=12)])
], fluid=True)

# --- 3. LOGICA FILTRI ---
def get_filtered_df(anno, sesso, evento, naz, cpi, eta):
    dff = df.copy()
    if anno: dff = dff[dff['ANNO_EVENTO'].isin(anno)]
    if sesso: dff = dff[dff['SESSO_LAV'].isin(sesso)]
    if evento: dff = dff[dff['TIPO_EVENTO'].isin(evento)]
    if naz:
        if 'TOP_10' in naz or 'TOP_25' in naz:
            n = 10 if 'TOP_10' in naz else 25
            top_list = df['NAZIONALITA'].value_counts().nlargest(n).index.tolist()
            dff = dff[dff['NAZIONALITA'].isin(top_list)]
        else:
            dff = dff[dff['NAZIONALITA'].isin(naz)]
    if cpi: dff = dff[dff['nome_CPI_sede_lavoro'].isin(cpi)]
    if eta: dff = dff[(dff['ETA_LAV'] >= eta[0]) & (dff['ETA_LAV'] <= eta[1])]
    return dff

# --- 4. CALLBACKS ---

@callback(Output('store-contratto-sel', 'data'), Input('graph-contracts', 'clickData'), State('store-contratto-sel', 'data'))
def toggle_c(click, curr):
    if not click: return None
    new = click['points'][0]['y']
    return None if new == curr else new

@callback(Output('store-target-sel', 'data'), Input('graph-target', 'clickData'), State('store-target-sel', 'data'))
def toggle_t(click, curr):
    if not click: return None
    val = click['points'][0]['customdata'][0]
    return None if val == curr else val

@callback([Output('graph-contracts', 'figure'), Output('table-container', 'children')], 
          [Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), Input('store-contratto-sel', 'data')])
def update_g1(anno, sesso, evento, naz, cpi, eta, sel_c):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    dff['VIZ'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
    counts = dff['VIZ'].value_counts()
    top = counts.nlargest(24).reset_index()
    top.columns = ['VIZ', 'count']
    if len(counts) > 24:
        top = pd.concat([top, pd.DataFrame({'VIZ': ['Altre Tipologie'], 'count': [counts.iloc[24:].sum()]})], ignore_index=True)
    top['percentage'] = (top['count'] / top['count'].sum() * 100).round(1)
    top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    
    fig = px.bar(top, y='VIZ', x='count', orientation='h', template="plotly_white", text='label_text', title="Distribuzione Contratti")
    fig.update_traces(marker_color=['#e74c3c' if v == sel_c else ('#2c3e50' if sel_c is None else '#bdc3c7') for v in top['VIZ']], textposition='auto')
    fig = refine_fig_layout(fig, is_trend=False)
    
    fig.write_html(f"{export_dir}/grafico_1.html", include_plotlyjs='cdn')
    fig.write_image(f"{export_dir}/grafico_1.png")
    force_utf8(f"{export_dir}/grafico_1.html")
    
    pivot = pd.crosstab(dff['VIZ'], dff['SESSO_LAV'], margins=True).reset_index()
    return fig, dash_table.DataTable(data=pivot.to_dict('records'), page_size=10)

@callback(
    Output('graph-target', 'figure'), 
    [Input('store-contratto-sel', 'data'), Input('target-dimension', 'value'), 
     Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), 
     Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value'), 
     Input('store-target-sel', 'data')]
)
def update_g2(sel_c, target_dim, anno, sesso, evento, naz, cpi, eta, sel_t):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    
    # Filtro opzionale basato sulla selezione del Grafico 1
    if sel_c:
        dff['VIZ_C'] = dff['TIPOLOGIA_CONTRATTUALE'].apply(lambda x: (str(x)[:40] + '...') if len(str(x)) > 43 else x)
        if sel_c == 'Altre Tipologie':
            top_24_esclusi = dff['VIZ_C'].value_counts().nlargest(24).index
            dff = dff[~dff['VIZ_C'].isin(top_24_esclusi)]
        else:
            dff = dff[dff['VIZ_C'] == sel_c]
    
    # Preparazione dati Top 25 (Qualifiche o ATECO)
    top = dff[target_dim].value_counts().nlargest(25).reset_index()
    top.columns = [target_dim, 'count']
    
    # Calcolo percentuali e testo etichette
    total_count = top['count'].sum()
    if total_count > 0:
        top['percentage'] = (top['count'] / total_count * 100).round(1)
        top['label_text'] = top.apply(lambda r: f"{r['count']} ({r['percentage']}%)", axis=1)
    else:
        top['label_text'] = ""

    # Tronca i nomi lunghi per la visualizzazione sull'asse Y
    top['VIZ_T'] = top[target_dim].apply(lambda x: (str(x)[:50] + '...') if len(str(x)) > 53 else x)
    
    # Creazione Grafico
    fig = px.bar(
        top, 
        y='VIZ_T', 
        x='count', 
        orientation='h', 
        template="plotly_white", 
        text='label_text', # <-- Visualizza etichette calcolate
        title=f"Dettaglio {MAPPA_NOMI_VISTE.get(target_dim)}", 
        custom_data=[target_dim]
    )
    
    # Logica colori e posizionamento testo
    colors = ['#e74c3c' if v == sel_t else ('#16a085' if sel_t is None else '#bdc3c7') for v in top[target_dim]]
    
    fig.update_traces(
        marker_color=colors, 
        textposition='auto', # <-- Posiziona il testo dentro o fuori le barre automaticamente
        hovertemplate="<b>%{customdata[0]}</b><br>Conteggio: %{x}<extra></extra>"
    )
    
    fig = refine_fig_layout(fig, is_trend=False)
    
    # Esportazione file
    try:
        fig.write_html(f"{export_dir}/grafico_2.html", include_plotlyjs='cdn')
        fig.write_image(f"{export_dir}/grafico_2.png")
        force_utf8(f"{export_dir}/grafico_2.html")
    except:
        pass
        
    return fig


@callback([Output('trend-contracts-sesso', 'figure'), Output('trend-contracts-evento', 'figure'), Output('trend-contracts-naz', 'figure'), Output('trend-contracts-cpi', 'figure'), Output('trend-contracts-eta', 'figure'), 
           Output('title-3', 'children'), Output('title-5', 'children'), Output('title-7', 'children'), Output('title-9', 'children'), Output('title-11', 'children')], 
          [Input('store-contratto-sel', 'data'), Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')])
def update_t_left(sel_c, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    label = sel_c if sel_c else "Tutti i contratti"
    
    n_view = 25 if (naz and 'TOP_25' in naz) else 10
    
    f3 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f5 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    f7 = px.line(dff[dff['NAZIONALITA'].isin(dff['NAZIONALITA'].value_counts().nlargest(n_view).index)].groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, title=f"Trend Top {n_view} Nazionalità: {label}")
    f9 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f11 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età: {label}")
    
    for idx, f in enumerate([f3, f5, f7, f9, f11]):
        f = refine_fig_layout(f, is_trend=True)
        num = 3 + (idx * 2)
        f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
        f.write_image(f"{export_dir}/grafico_{num}.png")
        force_utf8(f"{export_dir}/grafico_{num}.html")
        
    return f3, f5, f7, f9, f11, f"3. {label}", f"5. {label}", f"7. {label}", f"9. {label}", f"11. {label}"

@callback([Output('trend-target-sesso', 'figure'), Output('trend-target-evento', 'figure'), Output('trend-target-naz', 'figure'), Output('trend-target-cpi', 'figure'), Output('trend-target-eta', 'figure'), 
           Output('title-4', 'children'), Output('title-6', 'children'), Output('title-8', 'children'), Output('title-10', 'children'), Output('title-12', 'children')], 
          [Input('store-target-sel', 'data'), Input('target-dimension', 'value'), Input('f-anno', 'value'), Input('f-sesso', 'value'), Input('f-evento', 'value'), Input('f-nazionalita', 'value'), Input('f-cpi', 'value'), Input('f-eta', 'value')])
def update_t_right(sel_t, target_dim, anno, sesso, evento, naz, cpi, eta):
    dff = get_filtered_df(anno, sesso, evento, naz, cpi, eta)
    label = sel_t if sel_t else f"Top 25 {MAPPA_NOMI_VISTE.get(target_dim)}"
    if sel_t: dff = dff[dff[target_dim] == sel_t]
    
    n_view = 25 if (naz and 'TOP_25' in naz) else 10
    
    f4 = px.line(dff.groupby(['ANNO_EVENTO', 'SESSO_LAV']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='SESSO_LAV', markers=True, color_discrete_map=color_map_sesso, title=f"Trend Genere: {label}")
    f6 = px.line(dff.groupby(['ANNO_EVENTO', 'TIPO_EVENTO']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='TIPO_EVENTO', markers=True, title=f"Trend Evento: {label}")
    f8 = px.line(dff[dff['NAZIONALITA'].isin(dff['NAZIONALITA'].value_counts().nlargest(n_view).index)].groupby(['ANNO_EVENTO', 'NAZIONALITA']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='NAZIONALITA', markers=True, title=f"Trend Top {n_view} Nazionalità: {label}")
    f10 = px.line(dff.groupby(['ANNO_EVENTO', 'nome_CPI_sede_lavoro']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='nome_CPI_sede_lavoro', markers=True, title=f"Trend CPI: {label}")
    f12 = px.line(dff.groupby(['ANNO_EVENTO', 'ETA_LAV_ISTAT']).size().reset_index(name='C'), x='ANNO_EVENTO', y='C', color='ETA_LAV_ISTAT', markers=True, title=f"Trend Età: {label}")
    
    for idx, f in enumerate([f4, f6, f8, f10, f12]):
        f = refine_fig_layout(f, is_trend=True)
        num = 4 + (idx * 2)
        f.write_html(f"{export_dir}/grafico_{num}.html", include_plotlyjs='cdn')
        f.write_image(f"{export_dir}/grafico_{num}.png")
        force_utf8(f"{export_dir}/grafico_{num}.html")
        
    return f4, f6, f8, f10, f12, f"4. {label}", f"6. {label}", f"8. {label}", f"10. {label}", f"12. {label}"

if __name__ == '__main__':
    app.run(mode="inline", port=8056)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8056/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
